# %% [markdown]
# # 1. Informations sur le Dataset BraTS 2020
#
# Le jeu de données de segmentation des tumeurs cérébrales (BraTS) 2020 est une collection de scans d'imagerie par résonance magnétique (IRM) multimodaux utilisée pour la segmentation des tumeurs cérébrales.
#
# Il comprend des scans IRM de patients atteints de gliomes, fournissant quatre modalités IRM différentes (ce qui signifie 4 canaux d'informations - 4 volumes différents de la même région) par patient :
#
# 1. T1 natif (T1)
# 2. T1 post-contraste (T1ce - contraste amélioré)
# 3. T2 pondéré (T2)
# 4. T2-FLAIR (T2 - récupération de l'inversion atténuée par le fluide)
#
# Ces scans sont accompagnés de masques de segmentation annotés par des experts, délimitant la tumeur en différentes sous-régions, telles que le noyau tumoral nécrotique et non rehaussé, l'œdème péritumoral et la tumeur rehaussée.
#
# Annotations (étiquettes) :
#
# * Étiquette 0 : Volume sans tumeur (NT)
# * Étiquette 1 : Noyau tumoral nécrotique et non rehaussé (NCR/NET)
# * Étiquette 2 : Œdème péritumoral (ED)
# * Étiquette 3 : Manquant (Aucun pixel dans tous les volumes ne contient l'étiquette 3)
# * Étiquette 4 : Tumeur rehaussée par GD (ET)
#
# Comme il n'y a pas de pixels avec l'étiquette 3, nous remplacerons l'étiquette 3 par l'étiquette 4 afin qu'il y ait une continuité entre les étiquettes.

# %% [markdown]
# Maintenant que nous avons chargé le jeu de données, explorons-le et comprenons-le !
#
# Dans le dossier **brats20-dataset-training-validation**, vous trouverez deux ensembles de données : un pour l'entraînement et un pour la validation. Si vous ouvrez le dossier **BraTS2020_TrainingData**, vous remarquerez qu'il contient un autre dossier, qui contient 369 échantillons (qui représentent ici les patients).
#
# Chaque patient est représenté par un sous-dossier qui comprend les scans IRM pour chaque modalité (T1, T1ce, T2, FLAIR) ainsi que les masques de segmentation associés. Vous pouvez alors analyser les images et observer les annotations qui délimitent les régions tumorales. Ces données sont essentielles pour former un modèle de segmentation des tumeurs cérébrales, car elles fournissent des informations sur l'anatomie cérébrale et les tumeurs.

# %% [markdown]
# # 2. Preparer l'environnement

# %% [markdown]
# # 3. Importation des Librairies
#
# Avant de commencer, nous devons importer les bibliothèques nécessaires pour le traitement des données, l'entraînement du modèle et l'évaluation des performances.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.11/dist-packages (1.7.4.5)
# Requirement already satisfied: bleach in /usr/local/lib/python3.11/dist-packages (from kaggle) (6.2.0)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2025.4.26)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.11/dist-packages (from kaggle) (3.4.2)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from kaggle) (3.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from kaggle) (5.29.4)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.11/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.32.3)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.11/dist-packages (from kaggle) (75.2.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.11/dist-packages (from kaggle) (1.17.0)
# Requirement already satisfied: text-unidecode in /usr/local/lib/python3.11/dist-packages (from kaggle) (1.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from kaggle) (4.67.1)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.4.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from kaggle) (0.5.1)

# %%
! mkdir ~/.kaggle

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download awsaf49/brats20-dataset-training-validation
# Out:
# Dataset URL: https://www.kaggle.com/datasets/awsaf49/brats20-dataset-training-validation
# License(s): CC0-1.0
# Downloading brats20-dataset-training-validation.zip to /content
# 100% 4.16G/4.16G [00:43<00:00, 117MB/s]
# 100% 4.16G/4.16G [00:44<00:00, 100MB/s]

# %%
! unzip brats20-dataset-training-validation.zip
# Out:
# Archive:  brats20-dataset-training-validation.zip
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_001/BraTS20_Training_001_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_001/BraTS20_Training_001_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_001/BraTS20_Training_001_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_001/BraTS20_Training_001_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_001/BraTS20_Training_001_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_002/BraTS20_Training_002_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_002/BraTS20_Training_002_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_002/BraTS20_Training_002_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_002/BraTS20_Training_002_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_002/BraTS20_Training_002_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_003/BraTS20_Training_003_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_003/BraTS20_Training_003_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_003/BraTS20_Training_003_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_003/BraTS20_Training_003_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_003/BraTS20_Training_003_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_004/BraTS20_Training_004_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_004/BraTS20_Training_004_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_004/BraTS20_Training_004_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_004/BraTS20_Training_004_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_004/BraTS20_Training_004_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_005/BraTS20_Training_005_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_005/BraTS20_Training_005_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_005/BraTS20_Training_005_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_005/BraTS20_Training_005_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_005/BraTS20_Training_005_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_006/BraTS20_Training_006_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_006/BraTS20_Training_006_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_006/BraTS20_Training_006_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_006/BraTS20_Training_006_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_006/BraTS20_Training_006_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_007/BraTS20_Training_007_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_007/BraTS20_Training_007_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_007/BraTS20_Training_007_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_007/BraTS20_Training_007_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_007/BraTS20_Training_007_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_008/BraTS20_Training_008_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_008/BraTS20_Training_008_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_008/BraTS20_Training_008_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_008/BraTS20_Training_008_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_008/BraTS20_Training_008_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_009/BraTS20_Training_009_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_009/BraTS20_Training_009_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_009/BraTS20_Training_009_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_009/BraTS20_Training_009_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_009/BraTS20_Training_009_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_010/BraTS20_Training_010_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_010/BraTS20_Training_010_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_010/BraTS20_Training_010_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_010/BraTS20_Training_010_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_010/BraTS20_Training_010_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_011/BraTS20_Training_011_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_011/BraTS20_Training_011_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_011/BraTS20_Training_011_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_011/BraTS20_Training_011_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_011/BraTS20_Training_011_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_012/BraTS20_Training_012_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_012/BraTS20_Training_012_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_012/BraTS20_Training_012_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_012/BraTS20_Training_012_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_012/BraTS20_Training_012_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_013/BraTS20_Training_013_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_013/BraTS20_Training_013_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_013/BraTS20_Training_013_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_013/BraTS20_Training_013_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_013/BraTS20_Training_013_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_014/BraTS20_Training_014_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_014/BraTS20_Training_014_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_014/BraTS20_Training_014_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_014/BraTS20_Training_014_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_014/BraTS20_Training_014_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_015/BraTS20_Training_015_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_015/BraTS20_Training_015_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_015/BraTS20_Training_015_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_015/BraTS20_Training_015_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_015/BraTS20_Training_015_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_016/BraTS20_Training_016_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_016/BraTS20_Training_016_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_016/BraTS20_Training_016_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_016/BraTS20_Training_016_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_016/BraTS20_Training_016_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_017/BraTS20_Training_017_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_017/BraTS20_Training_017_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_017/BraTS20_Training_017_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_017/BraTS20_Training_017_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_017/BraTS20_Training_017_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_018/BraTS20_Training_018_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_018/BraTS20_Training_018_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_018/BraTS20_Training_018_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_018/BraTS20_Training_018_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_018/BraTS20_Training_018_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_019/BraTS20_Training_019_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_019/BraTS20_Training_019_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_019/BraTS20_Training_019_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_019/BraTS20_Training_019_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_019/BraTS20_Training_019_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_020/BraTS20_Training_020_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_020/BraTS20_Training_020_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_020/BraTS20_Training_020_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_020/BraTS20_Training_020_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_020/BraTS20_Training_020_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_021/BraTS20_Training_021_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_021/BraTS20_Training_021_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_021/BraTS20_Training_021_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_021/BraTS20_Training_021_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_021/BraTS20_Training_021_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_022/BraTS20_Training_022_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_022/BraTS20_Training_022_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_022/BraTS20_Training_022_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_022/BraTS20_Training_022_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_022/BraTS20_Training_022_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_023/BraTS20_Training_023_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_023/BraTS20_Training_023_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_023/BraTS20_Training_023_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_023/BraTS20_Training_023_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_023/BraTS20_Training_023_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_024/BraTS20_Training_024_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_024/BraTS20_Training_024_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_024/BraTS20_Training_024_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_024/BraTS20_Training_024_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_024/BraTS20_Training_024_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_025/BraTS20_Training_025_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_025/BraTS20_Training_025_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_025/BraTS20_Training_025_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_025/BraTS20_Training_025_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_025/BraTS20_Training_025_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_026/BraTS20_Training_026_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_026/BraTS20_Training_026_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_026/BraTS20_Training_026_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_026/BraTS20_Training_026_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_026/BraTS20_Training_026_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_027/BraTS20_Training_027_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_027/BraTS20_Training_027_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_027/BraTS20_Training_027_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_027/BraTS20_Training_027_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_027/BraTS20_Training_027_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_028/BraTS20_Training_028_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_028/BraTS20_Training_028_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_028/BraTS20_Training_028_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_028/BraTS20_Training_028_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_028/BraTS20_Training_028_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_029/BraTS20_Training_029_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_029/BraTS20_Training_029_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_029/BraTS20_Training_029_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_029/BraTS20_Training_029_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_029/BraTS20_Training_029_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_030/BraTS20_Training_030_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_030/BraTS20_Training_030_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_030/BraTS20_Training_030_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_030/BraTS20_Training_030_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_030/BraTS20_Training_030_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_031/BraTS20_Training_031_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_031/BraTS20_Training_031_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_031/BraTS20_Training_031_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_031/BraTS20_Training_031_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_031/BraTS20_Training_031_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_032/BraTS20_Training_032_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_032/BraTS20_Training_032_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_032/BraTS20_Training_032_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_032/BraTS20_Training_032_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_032/BraTS20_Training_032_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_033/BraTS20_Training_033_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_033/BraTS20_Training_033_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_033/BraTS20_Training_033_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_033/BraTS20_Training_033_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_033/BraTS20_Training_033_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_034/BraTS20_Training_034_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_034/BraTS20_Training_034_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_034/BraTS20_Training_034_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_034/BraTS20_Training_034_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_034/BraTS20_Training_034_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_035/BraTS20_Training_035_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_035/BraTS20_Training_035_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_035/BraTS20_Training_035_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_035/BraTS20_Training_035_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_035/BraTS20_Training_035_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_036/BraTS20_Training_036_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_036/BraTS20_Training_036_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_036/BraTS20_Training_036_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_036/BraTS20_Training_036_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_036/BraTS20_Training_036_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_037/BraTS20_Training_037_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_037/BraTS20_Training_037_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_037/BraTS20_Training_037_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_037/BraTS20_Training_037_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_037/BraTS20_Training_037_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_038/BraTS20_Training_038_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_038/BraTS20_Training_038_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_038/BraTS20_Training_038_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_038/BraTS20_Training_038_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_038/BraTS20_Training_038_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_039/BraTS20_Training_039_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_039/BraTS20_Training_039_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_039/BraTS20_Training_039_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_039/BraTS20_Training_039_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_039/BraTS20_Training_039_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_040/BraTS20_Training_040_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_040/BraTS20_Training_040_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_040/BraTS20_Training_040_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_040/BraTS20_Training_040_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_040/BraTS20_Training_040_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_041/BraTS20_Training_041_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_041/BraTS20_Training_041_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_041/BraTS20_Training_041_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_041/BraTS20_Training_041_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_041/BraTS20_Training_041_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_042/BraTS20_Training_042_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_042/BraTS20_Training_042_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_042/BraTS20_Training_042_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_042/BraTS20_Training_042_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_042/BraTS20_Training_042_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_043/BraTS20_Training_043_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_043/BraTS20_Training_043_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_043/BraTS20_Training_043_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_043/BraTS20_Training_043_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_043/BraTS20_Training_043_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_044/BraTS20_Training_044_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_044/BraTS20_Training_044_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_044/BraTS20_Training_044_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_044/BraTS20_Training_044_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_044/BraTS20_Training_044_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_045/BraTS20_Training_045_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_045/BraTS20_Training_045_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_045/BraTS20_Training_045_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_045/BraTS20_Training_045_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_045/BraTS20_Training_045_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_046/BraTS20_Training_046_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_046/BraTS20_Training_046_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_046/BraTS20_Training_046_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_046/BraTS20_Training_046_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_046/BraTS20_Training_046_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_047/BraTS20_Training_047_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_047/BraTS20_Training_047_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_047/BraTS20_Training_047_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_047/BraTS20_Training_047_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_047/BraTS20_Training_047_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_048/BraTS20_Training_048_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_048/BraTS20_Training_048_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_048/BraTS20_Training_048_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_048/BraTS20_Training_048_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_048/BraTS20_Training_048_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_049/BraTS20_Training_049_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_049/BraTS20_Training_049_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_049/BraTS20_Training_049_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_049/BraTS20_Training_049_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_049/BraTS20_Training_049_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_050/BraTS20_Training_050_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_050/BraTS20_Training_050_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_050/BraTS20_Training_050_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_050/BraTS20_Training_050_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_050/BraTS20_Training_050_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_051/BraTS20_Training_051_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_051/BraTS20_Training_051_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_051/BraTS20_Training_051_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_051/BraTS20_Training_051_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_051/BraTS20_Training_051_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_052/BraTS20_Training_052_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_052/BraTS20_Training_052_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_052/BraTS20_Training_052_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_052/BraTS20_Training_052_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_052/BraTS20_Training_052_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_053/BraTS20_Training_053_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_053/BraTS20_Training_053_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_053/BraTS20_Training_053_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_053/BraTS20_Training_053_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_053/BraTS20_Training_053_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_054/BraTS20_Training_054_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_054/BraTS20_Training_054_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_054/BraTS20_Training_054_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_054/BraTS20_Training_054_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_054/BraTS20_Training_054_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_055/BraTS20_Training_055_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_055/BraTS20_Training_055_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_055/BraTS20_Training_055_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_055/BraTS20_Training_055_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_055/BraTS20_Training_055_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_056/BraTS20_Training_056_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_056/BraTS20_Training_056_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_056/BraTS20_Training_056_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_056/BraTS20_Training_056_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_056/BraTS20_Training_056_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_057/BraTS20_Training_057_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_057/BraTS20_Training_057_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_057/BraTS20_Training_057_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_057/BraTS20_Training_057_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_057/BraTS20_Training_057_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_058/BraTS20_Training_058_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_058/BraTS20_Training_058_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_058/BraTS20_Training_058_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_058/BraTS20_Training_058_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_058/BraTS20_Training_058_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_059/BraTS20_Training_059_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_059/BraTS20_Training_059_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_059/BraTS20_Training_059_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_059/BraTS20_Training_059_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_059/BraTS20_Training_059_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_060/BraTS20_Training_060_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_060/BraTS20_Training_060_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_060/BraTS20_Training_060_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_060/BraTS20_Training_060_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_060/BraTS20_Training_060_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_061/BraTS20_Training_061_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_061/BraTS20_Training_061_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_061/BraTS20_Training_061_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_061/BraTS20_Training_061_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_061/BraTS20_Training_061_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_062/BraTS20_Training_062_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_062/BraTS20_Training_062_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_062/BraTS20_Training_062_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_062/BraTS20_Training_062_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_062/BraTS20_Training_062_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_063/BraTS20_Training_063_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_063/BraTS20_Training_063_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_063/BraTS20_Training_063_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_063/BraTS20_Training_063_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_063/BraTS20_Training_063_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_064/BraTS20_Training_064_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_064/BraTS20_Training_064_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_064/BraTS20_Training_064_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_064/BraTS20_Training_064_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_064/BraTS20_Training_064_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_065/BraTS20_Training_065_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_065/BraTS20_Training_065_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_065/BraTS20_Training_065_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_065/BraTS20_Training_065_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_065/BraTS20_Training_065_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_066/BraTS20_Training_066_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_066/BraTS20_Training_066_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_066/BraTS20_Training_066_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_066/BraTS20_Training_066_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_066/BraTS20_Training_066_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_067/BraTS20_Training_067_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_067/BraTS20_Training_067_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_067/BraTS20_Training_067_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_067/BraTS20_Training_067_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_067/BraTS20_Training_067_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_068/BraTS20_Training_068_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_068/BraTS20_Training_068_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_068/BraTS20_Training_068_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_068/BraTS20_Training_068_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_068/BraTS20_Training_068_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_069/BraTS20_Training_069_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_069/BraTS20_Training_069_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_069/BraTS20_Training_069_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_069/BraTS20_Training_069_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_069/BraTS20_Training_069_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_070/BraTS20_Training_070_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_070/BraTS20_Training_070_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_070/BraTS20_Training_070_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_070/BraTS20_Training_070_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_070/BraTS20_Training_070_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_071/BraTS20_Training_071_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_071/BraTS20_Training_071_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_071/BraTS20_Training_071_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_071/BraTS20_Training_071_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_071/BraTS20_Training_071_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_072/BraTS20_Training_072_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_072/BraTS20_Training_072_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_072/BraTS20_Training_072_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_072/BraTS20_Training_072_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_072/BraTS20_Training_072_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_073/BraTS20_Training_073_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_073/BraTS20_Training_073_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_073/BraTS20_Training_073_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_073/BraTS20_Training_073_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_073/BraTS20_Training_073_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_074/BraTS20_Training_074_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_074/BraTS20_Training_074_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_074/BraTS20_Training_074_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_074/BraTS20_Training_074_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_074/BraTS20_Training_074_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_075/BraTS20_Training_075_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_075/BraTS20_Training_075_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_075/BraTS20_Training_075_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_075/BraTS20_Training_075_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_075/BraTS20_Training_075_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_076/BraTS20_Training_076_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_076/BraTS20_Training_076_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_076/BraTS20_Training_076_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_076/BraTS20_Training_076_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_076/BraTS20_Training_076_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_077/BraTS20_Training_077_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_077/BraTS20_Training_077_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_077/BraTS20_Training_077_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_077/BraTS20_Training_077_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_077/BraTS20_Training_077_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_078/BraTS20_Training_078_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_078/BraTS20_Training_078_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_078/BraTS20_Training_078_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_078/BraTS20_Training_078_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_078/BraTS20_Training_078_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_079/BraTS20_Training_079_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_079/BraTS20_Training_079_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_079/BraTS20_Training_079_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_079/BraTS20_Training_079_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_079/BraTS20_Training_079_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_080/BraTS20_Training_080_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_080/BraTS20_Training_080_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_080/BraTS20_Training_080_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_080/BraTS20_Training_080_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_080/BraTS20_Training_080_t2.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_081/BraTS20_Training_081_flair.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_081/BraTS20_Training_081_seg.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_081/BraTS20_Training_081_t1.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_081/BraTS20_Training_081_t1ce.nii
#   inflating: BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_081/BraTS20_Training_081_t2.nii
# ...
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_094/BraTS20_Validation_094_t2.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_095/BraTS20_Validation_095_flair.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_095/BraTS20_Validation_095_t1.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_095/BraTS20_Validation_095_t1ce.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_095/BraTS20_Validation_095_t2.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_096/BraTS20_Validation_096_flair.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_096/BraTS20_Validation_096_t1.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_096/BraTS20_Validation_096_t1ce.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_096/BraTS20_Validation_096_t2.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_097/BraTS20_Validation_097_flair.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_097/BraTS20_Validation_097_t1.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_097/BraTS20_Validation_097_t1ce.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_097/BraTS20_Validation_097_t2.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_098/BraTS20_Validation_098_flair.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_098/BraTS20_Validation_098_t1.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_098/BraTS20_Validation_098_t1ce.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_098/BraTS20_Validation_098_t2.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_099/BraTS20_Validation_099_flair.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_099/BraTS20_Validation_099_t1.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_099/BraTS20_Validation_099_t1ce.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_099/BraTS20_Validation_099_t2.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_100/BraTS20_Validation_100_flair.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_100/BraTS20_Validation_100_t1.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_100/BraTS20_Validation_100_t1ce.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_100/BraTS20_Validation_100_t2.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_101/BraTS20_Validation_101_flair.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_101/BraTS20_Validation_101_t1.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_101/BraTS20_Validation_101_t1ce.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_101/BraTS20_Validation_101_t2.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_102/BraTS20_Validation_102_flair.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_102/BraTS20_Validation_102_t1.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_102/BraTS20_Validation_102_t1ce.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_102/BraTS20_Validation_102_t2.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_103/BraTS20_Validation_103_flair.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_103/BraTS20_Validation_103_t1.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_103/BraTS20_Validation_103_t1ce.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_103/BraTS20_Validation_103_t2.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_104/BraTS20_Validation_104_flair.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_104/BraTS20_Validation_104_t1.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_104/BraTS20_Validation_104_t1ce.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_104/BraTS20_Validation_104_t2.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_105/BraTS20_Validation_105_flair.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_105/BraTS20_Validation_105_t1.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_105/BraTS20_Validation_105_t1ce.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_105/BraTS20_Validation_105_t2.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_106/BraTS20_Validation_106_flair.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_106/BraTS20_Validation_106_t1.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_106/BraTS20_Validation_106_t1ce.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_106/BraTS20_Validation_106_t2.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_107/BraTS20_Validation_107_flair.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_107/BraTS20_Validation_107_t1.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_107/BraTS20_Validation_107_t1ce.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_107/BraTS20_Validation_107_t2.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_108/BraTS20_Validation_108_flair.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_108/BraTS20_Validation_108_t1.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_108/BraTS20_Validation_108_t1ce.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_108/BraTS20_Validation_108_t2.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_109/BraTS20_Validation_109_flair.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_109/BraTS20_Validation_109_t1.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_109/BraTS20_Validation_109_t1ce.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_109/BraTS20_Validation_109_t2.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_110/BraTS20_Validation_110_flair.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_110/BraTS20_Validation_110_t1.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_110/BraTS20_Validation_110_t1ce.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_110/BraTS20_Validation_110_t2.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_111/BraTS20_Validation_111_flair.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_111/BraTS20_Validation_111_t1.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_111/BraTS20_Validation_111_t1ce.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_111/BraTS20_Validation_111_t2.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_112/BraTS20_Validation_112_flair.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_112/BraTS20_Validation_112_t1.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_112/BraTS20_Validation_112_t1ce.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_112/BraTS20_Validation_112_t2.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_113/BraTS20_Validation_113_flair.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_113/BraTS20_Validation_113_t1.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_113/BraTS20_Validation_113_t1ce.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_113/BraTS20_Validation_113_t2.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_114/BraTS20_Validation_114_flair.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_114/BraTS20_Validation_114_t1.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_114/BraTS20_Validation_114_t1ce.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_114/BraTS20_Validation_114_t2.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_115/BraTS20_Validation_115_flair.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_115/BraTS20_Validation_115_t1.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_115/BraTS20_Validation_115_t1ce.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_115/BraTS20_Validation_115_t2.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_116/BraTS20_Validation_116_flair.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_116/BraTS20_Validation_116_t1.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_116/BraTS20_Validation_116_t1ce.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_116/BraTS20_Validation_116_t2.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_117/BraTS20_Validation_117_flair.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_117/BraTS20_Validation_117_t1.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_117/BraTS20_Validation_117_t1ce.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_117/BraTS20_Validation_117_t2.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_118/BraTS20_Validation_118_flair.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_118/BraTS20_Validation_118_t1.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_118/BraTS20_Validation_118_t1ce.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_118/BraTS20_Validation_118_t2.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_119/BraTS20_Validation_119_flair.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_119/BraTS20_Validation_119_t1.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_119/BraTS20_Validation_119_t1ce.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_119/BraTS20_Validation_119_t2.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_120/BraTS20_Validation_120_flair.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_120/BraTS20_Validation_120_t1.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_120/BraTS20_Validation_120_t1ce.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_120/BraTS20_Validation_120_t2.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_121/BraTS20_Validation_121_flair.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_121/BraTS20_Validation_121_t1.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_121/BraTS20_Validation_121_t1ce.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_121/BraTS20_Validation_121_t2.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_122/BraTS20_Validation_122_flair.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_122/BraTS20_Validation_122_t1.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_122/BraTS20_Validation_122_t1ce.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_122/BraTS20_Validation_122_t2.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_123/BraTS20_Validation_123_flair.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_123/BraTS20_Validation_123_t1.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_123/BraTS20_Validation_123_t1ce.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_123/BraTS20_Validation_123_t2.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_124/BraTS20_Validation_124_flair.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_124/BraTS20_Validation_124_t1.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_124/BraTS20_Validation_124_t1ce.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_124/BraTS20_Validation_124_t2.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_125/BraTS20_Validation_125_flair.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_125/BraTS20_Validation_125_t1.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_125/BraTS20_Validation_125_t1ce.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/BraTS20_Validation_125/BraTS20_Validation_125_t2.nii
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/name_mapping_validation_data.csv
#   inflating: BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/survival_evaluation.csv

# %%
# importation des librairies et modules necessaires
import numpy as np
import nibabel as nib
import glob
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from tensorflow.keras.utils import to_categorical
# from tifffile import imsave
# import splitfolders
import os
import pandas as pd
from keras.models import Model
from keras.layers import Input, Conv3D, MaxPooling3D, concatenate, Conv3DTranspose, BatchNormalization, Dropout, Lambda
from keras.optimizers import Adam
from keras.metrics import MeanIoU
import cv2
from tensorflow.keras.utils import plot_model
from tensorflow.keras import layers
import tensorflow as tf
import matplotlib
from skimage.util import montage
from skimage.transform import rotate
import keras
import keras.backend as K
from keras.callbacks import CSVLogger
from tensorflow.keras.callbacks import ModelCheckpoint #, ReduceLROnPlateau, EarlyStopping, TensorBoard

# %% [markdown]
# # 4. Charger et Explorer le Jeu de Données

# %%
TRAIN_DATASET_PATH = "/content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/"

# %%
old_name = TRAIN_DATASET_PATH + "BraTS20_Training_355/W39_1998.09.19_Segm.nii"
new_name = TRAIN_DATASET_PATH + "BraTS20_Training_355/BraTS20_Training_355_seg.nii"

# renaming the file
try:
    os.rename(old_name, new_name)
    print("File has been re-named successfully!")
except:
    print("File is already renamed!")
# Out:
# File has been re-named successfully!

# %%
# load .nii file as a numpy array
test_image_flair=nib.load(TRAIN_DATASET_PATH + '/BraTS20_Training_004/BraTS20_Training_004_flair.nii').get_fdata()
print("Shape: ", test_image_flair.shape)
print("Dtype: ", test_image_flair.dtype)
# Out:
# Shape:  (240, 240, 155)
# Dtype:  float64

# %%
print("Min: ", test_image_flair.min())
print("Max: ", test_image_flair.max())
# Out:
# Min:  0.0
# Max:  757.0

# %% [markdown]
# La valeur maximale des pixels de l’image est de 757,0, ce qui suggère qu’un redimensionnement des valeurs est nécessaire. Cette étape est essentielle pour normaliser les intensités des différentes modalités d’IRM (T1, T1ce, T2, FLAIR) sur une même échelle. Une telle normalisation garantit une cohérence dans l'entraînement et l'analyse du modèle, en minimisant l'impact des variations d’intensité dues aux différences d’équipement et de modalités d’imagerie. Elle permet ainsi au modèle d’extraire des caractéristiques pertinentes et d’améliorer la précision de la segmentation tumorale, indépendamment des spécificités des images IRM brutes.

# %%
scaler = MinMaxScaler()

# %%
# Scale the test_image_flair array and then reshape it back to its original dimensions.
# This ensures the data is normalized/standardized for model input without altering its spatial structure.
test_image_flair = scaler.fit_transform(test_image_flair.reshape(-1, test_image_flair.shape[-1])).reshape(test_image_flair.shape)

# %%
print("Min: ", test_image_flair.min())
print("Max: ", test_image_flair.max())
# Out:
# Min:  0.0
# Max:  1.0

# %%
# rescaling t1
test_image_t1 = nib.load(TRAIN_DATASET_PATH + '/BraTS20_Training_004/BraTS20_Training_004_t1.nii').get_fdata()
test_image_t1 = scaler.fit_transform(test_image_t1.reshape(-1, test_image_t1.shape[-1])).reshape(test_image_t1.shape)

# rescaling t1ce
test_image_t1ce = nib.load(TRAIN_DATASET_PATH + '/BraTS20_Training_004/BraTS20_Training_004_t1ce.nii').get_fdata()
test_image_t1ce = scaler.fit_transform(test_image_t1ce.reshape(-1, test_image_t1ce.shape[-1])).reshape(test_image_t1ce.shape)

# rescaling t2
test_image_t2 = nib.load(TRAIN_DATASET_PATH + '/BraTS20_Training_004/BraTS20_Training_004_t2.nii').get_fdata()
test_image_t2 = scaler.fit_transform(test_image_t2.reshape(-1, test_image_t2.shape[-1])).reshape(test_image_t2.shape)

# we will not rescale the mask
test_image_seg = nib.load(TRAIN_DATASET_PATH + '/BraTS20_Training_004/BraTS20_Training_004_seg.nii').get_fdata()

# %%
slice = 95

print("Slice Number: " + str(slice))

plt.figure(figsize=(12, 8))

# T1
plt.subplot(2, 3, 1)
plt.imshow(test_image_t1[:,:,slice], cmap='gray')
plt.title('T1')

# T1ce
plt.subplot(2, 3, 2)
plt.imshow(test_image_t1ce[:,:,slice], cmap='gray')
plt.title('T1ce')

# T2
plt.subplot(2, 3, 3)
plt.imshow(test_image_t2[:,:,slice], cmap='gray')
plt.title('T2')

# Flair
plt.subplot(2, 3, 4)
plt.imshow(test_image_flair[:,:,slice], cmap='gray')
plt.title('FLAIR')

# Mask
plt.subplot(2, 3, 5)
plt.imshow(test_image_seg[:,:,slice])
plt.title('Mask')
plt.show()
# Out:
# Slice Number: 95

# %% [markdown]
# Les quatre modalités d’imagerie apportent des visions complémentaires d’une même image cérébrale, chacune mettant en avant des caractéristiques distinctes.
#
# Présentation des différentes modalités :
# * T1 (Native) : Permet d’observer la structure et la composition des tissus cérébraux, utile pour repérer des anomalies comme les tumeurs et les kystes.
# * T1 post-contraste (T1ce ou T1Gd) : Basé sur l’imagerie T1, mais avec l’ajout d’un agent de contraste (Gadolinium) qui améliore la détection des anomalies.
# * T2 pondéré (T2) : Met en évidence la présence de fluides dans les tissus cérébraux.
# * T2-FLAIR (Fluid Attenuated Inversion Recovery) : Supprime les signaux des fluides, ce qui facilite la détection des lésions moins visibles sur les images T1 ou T2, notamment celles affectant la substance blanche du cerveau.
#
# Ces quatre modalités, combinées, offrent aux spécialistes une vision détaillée pour une analyse et un diagnostic précis des tumeurs. Toutefois, dans le cadre de notre approche en intelligence artificielle, nous cherchons à optimiser l’efficacité du modèle en réduisant la charge de calcul et la mémoire utilisée. Pour cela, nous avons sélectionné uniquement deux modalités afin d’accélérer la segmentation tout en conservant la pertinence des données.
#
#
# Nous avons choisi d’exclure T1, car sa version améliorée T1ce offre une meilleure clarté. En revanche, nous avons retenu T1ce, T2 et T2-FLAIR, car ces modalités fournissent des informations complémentaires essentielles. T1ce améliore la visibilité des anomalies grâce au contraste, T2 met en avant la teneur en fluide des tissus, et T2-FLAIR permet de mieux distinguer les lésions en supprimant les signaux des fluides, rendant ainsi l’analyse plus précise.

# %% [markdown]
# ### Format des images
#
# Vous avez peut-être remarqué que ces images sont enregistrées au format **.nii**. Il s’agit de fichiers **NIfTI** (Neuroimaging Informatics Technology Initiative), couramment utilisés en neuroimagerie. Ce format permet de représenter numériquement des objets en trois dimensions, comme le cerveau dans notre cas. Il est particulièrement apprécié pour sa capacité à gérer efficacement des données complexes et multidimensionnelles, tout en intégrant des métadonnées essentielles sur l’orientation spatiale et l’échelle.
#
# Pour mieux comprendre la structure des données, examinons la forme d’un scan de modalité et d’un masque de segmentation. Il est important de noter que, dans ce jeu de données, toutes les modalités et leurs masques de segmentation correspondants ont les mêmes dimensions.:

# %%
# Modality shape
print("Modality: ", test_image_t1.shape)

# Segmentation shape
print("Segmentation: ", test_image_seg.shape)
# Out:
# Modality:  (240, 240, 155)
# Segmentation:  (240, 240, 155)

# %% [markdown]
# ##Dimensions et plans anatomiques
# Les modalités et les segmentations sont représentées en trois dimensions. Chacune de ces dimensions est constituée d’une série d’images bidimensionnelles, appelées coupes, qui possèdent toutes le même nombre de pixels et sont empilées pour former cette représentation 3D. Par exemple, dans notre illustration précédente, nous avons affiché la 95ᵉ coupe d’une certaine dimension.
#
# Ces trois dimensions correspondent aux trois plans spatiaux de l’image : largeur, hauteur et profondeur. En imagerie médicale, elles sont mieux connues sous les noms de plans axial, coronal et sagittal, qui reflètent les principales orientations du corps humain et, par extension, du cerveau.
#
# Présentation des trois plans :
# 1. Plan axial (transversal) : Sépare le corps en parties supérieure et inférieure, perpendiculairement à son axe longitudinal. En imagerie cérébrale, une coupe axiale correspond à une section horizontale du cerveau.
# 2. Plan coronal (frontal) : Divise le corps en parties antérieure (avant) et postérieure (arrière). Une coupe coronale dans le cerveau est une section verticale d’un côté à l’autre de la tête, séparant l’avant et l’arrière du cerveau.
# 3. Plan sagittal (latéral) : Sépare le corps en parties gauche et droite. En imagerie cérébrale, une coupe sagittale est une section verticale allant de l’avant vers l’arrière du cerveau, divisant les hémisphères.
#
# La compréhension de ces plans est essentielle pour interpréter correctement les images médicales et les exploiter efficacement dans les tâches de segmentation. Chaque plan offre une perspective unique, facilitant ainsi la localisation des structures anatomiques et l’identification des anomalies.

# %%
slice = 95

print("Slice number: " + str(slice))

plt.figure(figsize=(12, 8))

# Apply a 90° rotation with an automatic resizing, otherwise the display is less obvious to analyze
# T1 - Transverse View
plt.subplot(1, 3, 1)
plt.imshow(test_image_t1ce[:,:,slice], cmap='gray')
plt.title('T1 - Transverse View')

# T1 - Frontal View
plt.subplot(1, 3, 2)
plt.imshow(rotate(test_image_t1ce[:,slice,:], 90, resize=True), cmap='gray')
plt.title('T1 - Frontal View')

# T1 - Sagittal View
plt.subplot(1, 3, 3)
plt.imshow(rotate(test_image_t1ce[slice,:,:], 90, resize=True), cmap='gray')
plt.title('T1 - Sagittal View')
plt.show()
# Out:
# Slice number: 95

# %% [markdown]
# Maintenant que nous avons compris les trois dimensions de l’image, intéressons-nous au choix d’une coupe spécifique, ici la **95ᵉ**. En parcourant l’ensemble des coupes, nous pouvons identifier celle qui représente le mieux la **région d’intérêt**, notamment la zone tumorale.
#
# Pour illustrer cela, nous allons afficher l’ensemble des coupes selon une dimension donnée:

# %%
plt.figure(figsize=(10, 10))
plt.subplot(1, 1, 1)

# montage allows us to concatenate multiple images of the same size horizontally and vertically
plt.imshow(rotate(montage(test_image_t1ce[:,:,:]), 90, resize=True), cmap ='gray');

# %% [markdown]
# Comme vous pouvez le constater, deux zones noires apparaissent de part et d’autre de notre montage. Elles correspondent aux **premières et dernières coupes** du plan. Cela montre qu’une grande partie des coupes contient peu d’informations, ce qui est attendu puisque ces images représentent progressivement le cerveau d’une extrémité à l’autre.
#
# Cette observation est valable pour **toutes les modalités, tous les plans** et même pour les images segmentées par des experts. Ces derniers n’ont pas pu annoter les coupes dépourvues de détails significatifs, car elles capturent principalement des zones situées en dehors du cerveau ou des régions périphériques sans structures anatomiques pertinentes.
#
# Pour mieux illustrer cela, visualisons une série de coupes :

# %%
# Skip 50:-50 slices since there is not much to see
plt.figure(figsize=(10, 10))
plt.subplot(1, 1, 1)
plt.imshow(rotate(montage(test_image_t1ce[50:-50,:,:]), 90, resize=True), cmap ='gray');

# %%
# Skip 50:-50 slices since there is not much to see
plt.figure(figsize=(10, 10))
plt.subplot(1, 1, 1)
plt.imshow(rotate(montage(test_image_seg[50:-50,:,:]), 90, resize=True), cmap ='gray');

# %% [markdown]
# En nous concentrant sur une plage de coupes contenant des informations pertinentes, nous pouvons mieux appréhender les structures anatomiques et les zones susceptibles de présenter des anomalies, comme les tumeurs. Cette approche permet d’identifier les coupes les plus importantes pour l’analyse et la segmentation.
#
# Cette observation s’applique également à toutes les autres **modalités et plans**. Les images segmentées par les experts suivent le même schéma, en mettant l’accent sur les coupes riches en informations. Les coupes ne révélant qu’une faible portion de l’anatomie cérébrale sont souvent laissées non segmentées, car elles apportent peu ou pas de valeur pour le diagnostic ou l’analyse.

# %% [markdown]
# Concentrons-nous maintenant sur les segmentations fournies par les experts. Ces segmentations apportent des informations essentielles sur la tumeur :
#
# 1. **Localisation** : Détermine l’emplacement exact de la tumeur dans le cerveau.
# 2. **Taille et forme** : Permet de mesurer ses dimensions et sa morphologie.
# 3. **Type** : Aide à distinguer les différents types de tumeurs.
# 4. **Hétérogénéité** : Met en évidence les différentes composantes de la tumeur (tissu solide, zones nécrotiques, etc.).
# 5. **Interaction avec les tissus environnants** : Montre comment la tumeur affecte les structures cérébrales adjacentes.
# 6. **Comparaison inter-modalités** : Offre une vue globale en analysant les différences entre les modalités d’imagerie.

# %%
# Plotting the segmantation
cmap = matplotlib.colors.ListedColormap(['#440054', '#3b528b', '#18b880', '#e6d74f'])
norm = matplotlib.colors.BoundaryNorm([-0.5, 0.5, 1.5, 2.5, 3.5], cmap.N)

# plotting the 95th slice
plt.imshow(test_image_seg[:,:,95], cmap=cmap, norm=norm)
plt.colorbar()
plt.show()

# %%
# Isolation of class 0
seg_0 = test_image_seg.copy()
seg_0[seg_0 != 0] = np.nan

# Isolation of class 1
seg_1 = test_image_seg.copy()
seg_1[seg_1 != 1] = np.nan

# Isolation of class 2
seg_2 = test_image_seg.copy()
seg_2[seg_2 != 2] = np.nan

# Isolation of class 4
seg_4 = test_image_seg.copy()
seg_4[seg_4 != 4] = np.nan

# Define legend
class_names = ['class 0', 'class 1', 'class 2', 'class 4']
legend = [plt.Rectangle((0, 0), 1, 1, color=cmap(i), label=class_names[i]) for i in range(len(class_names))]

fig, ax = plt.subplots(1, 5, figsize=(20, 20))

ax[0].imshow(test_image_seg[:,:, slice], cmap=cmap, norm=norm)
ax[0].set_title('Original Segmentation')
ax[0].legend(handles=legend, loc='lower left')

ax[1].imshow(seg_0[:,:, slice], cmap=cmap, norm=norm)
ax[1].set_title('Not Tumor (class 0)')

ax[2].imshow(seg_1[:,:, slice], cmap=cmap, norm=norm)
ax[2].set_title('Non-Enhancing Tumor (class 1)')

ax[3].imshow(seg_2[:,:, slice], cmap=cmap, norm=norm)
ax[3].set_title('Edema (class 2)')

ax[4].imshow(seg_4[:,:, slice], cmap=cmap, norm=norm)
ax[4].set_title('Enhancing Tumor (class 4)')

plt.show()

# %% [markdown]
# Ces données sont indispensables pour un diagnostic fiable, une élaboration optimale du traitement et un suivi rigoureux. Les segmentations offrent une visualisation détaillée de la tumeur, ce qui aide à mieux appréhender ses particularités et ses interactions avec les structures voisines.

# %% [markdown]
# Pour résumer notre analyse des données :
#
# * **Modalités** : Chaque patient dispose de 4 modalités d'imagerie différentes (T1, T1CE, T2 et FLAIR), accompagnées d'une segmentation délimitant les zones tumorales.
# * **Modalités retenues** : Nous avons choisi de nous concentrer sur T1CE et FLAIR, car elles apportent des informations complémentaires sur l'anatomie cérébrale et le contraste des tissus.
# * **Images en 3D** : Les images sont en trois dimensions et peuvent être examinées sous trois plans différents, chacun composé de tranches 2D.
# * **Tranches significatives** : Un grand nombre de tranches ne contiennent que peu d'informations utiles. Nous nous concentrerons sur les tranches dans l'intervalle (50:-50), bien que ce choix puisse être ajusté, il impactera le temps d'entraînement.
# * **Classes de segmentation** : Les images de segmentation comportent de 1 à 4 classes. La classe 4 sera réaffectée à la classe 3, car cette dernière est absente.
# * **Classe de fond** : La classe 0 (le fond) est sur-représentée. Plutôt que de rogner les images, ce qui pourrait supprimer des informations cruciales, nous choisirons de les conserver telles quelles.
#
# Avec cette compréhension des données, nous pouvons désormais nous préparer à l'entraînement du modèle.

# %% [markdown]
# # 5. Split dataset
#
# Pour entraîner et évaluer efficacement notre modèle, nous devons diviser notre dataset en trois ensembles :
# - **Ensemble d'entraînement (80%)** : utilisé pour entraîner le modèle.
# - **Ensemble de validation (10%)** : permet d'ajuster les hyperparamètres et de prévenir le sur-apprentissage (*overfitting*).
# - **Ensemble de test (10%)** : utilisé pour évaluer les performances finales du modèle.
#
# Nous pouvons effectuer un fractionnement aléatoire des données ou un fractionnement stratifié, ce dernier permettant de conserver la même distribution des classes dans chaque ensemble, ce qui est particulièrement utile pour les datasets déséquilibrés. Un bon fractionnement garantit un modèle robuste et performant sur des données non vues.

# %%
from sklearn.model_selection import train_test_split
# Liste tous les patients (dossiers) dans le dataset
patients = [f for f in os.listdir(TRAIN_DATASET_PATH) if os.path.isdir(os.path.join(TRAIN_DATASET_PATH, f))]

# Mélange aléatoire des patients
np.random.shuffle(patients)

# Fractionnement des données (80% train, 10% val, 10% test)
train_patients, temp_patients = train_test_split(patients, test_size=0.2, random_state=42)
val_patients, test_patients = train_test_split(temp_patients, test_size=0.5, random_state=42)

# Afficher les tailles des ensembles
print(f"Nombre de patients dans l'ensemble d'entraînement : {len(train_patients)}")
print(f"Nombre de patients dans l'ensemble de validation : {len(val_patients)}")
print(f"Nombre de patients dans l'ensemble de test : {len(test_patients)}")
# Out:
# Nombre de patients dans l'ensemble d'entraînement : 295
# Nombre de patients dans l'ensemble de validation : 37
# Nombre de patients dans l'ensemble de test : 37

# %%
# Define seg-areas
SEGMENT_CLASSES = {
    0 : 'NOT tumor',
    1 : 'NECROTIC/CORE', # or NON-ENHANCING tumor CORE
    2 : 'EDEMA',
    3 : 'ENHANCING' # original 4 -> converted into 3
}

# Select Slices and Image Size
VOLUME_SLICES = 100
VOLUME_START_AT = 22 # first slice of volume that we will include
IMG_SIZE=128

# %% [markdown]
# # 6. Générateur de données (DataGenerator)
#
# Pour entraîner un réseau de neurones à la segmentation d’images, nous avons besoin à la fois des images brutes (X) et des segmentations de référence (y). Cela permet au réseau d’apprendre les motifs tumoraux et de faire des prédictions précises à partir des scans des patients. Cependant, charger directement toutes les images 3D peut surcharger la mémoire du système et provoquer des erreurs de dimensions. C’est pourquoi nous utilisons un générateur de données pour le prétraitement des images, qui suit plusieurs étapes :
#
# 1. **Récupération des chemins** : Obtenir les chemins des modalités FLAIR,T1CE et T2 (fournissant des informations complémentaires sur l’anatomie et le contraste tissulaire) ainsi que la segmentation de référence.
# 2. **Chargement des données** : Charger les tranches sélectionnées (60-135) de ces modalités et la segmentation correspondante.
# 3. **Création des tableaux** : Construire les tableaux X avec les tranches de FLAIR,T1CE et T2 et les tableaux y avec les tranches de segmentation.
# 4. **Réattribution des classes** : Assigner la valeur 3 à toutes les occurrences de 4 dans le masque afin de corriger le problème de classe manquante.

# %%
class DataGenerator(tf.keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, list_IDs, dim=(IMG_SIZE, IMG_SIZE), batch_size=1, n_channels=3, shuffle=True):
        'Initialization'
        self.dim = dim
        self.batch_size = batch_size
        self.list_IDs = list_IDs
        self.n_channels = n_channels  # Maintenant 3 canaux : FLAIR, T1CE, T2
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index * self.batch_size:(index + 1) * self.batch_size]

        # Find list of IDs
        Batch_ids = [self.list_IDs[k] for k in indexes]

        # Generate data
        X, y = self.__data_generation(Batch_ids)

        return X, y

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle:
            np.random.shuffle(self.indexes)

    def __data_generation(self, Batch_ids):
        'Generates data containing batch_size samples'
        # Initialization
        X = np.zeros((self.batch_size * VOLUME_SLICES, *self.dim, self.n_channels))  # 3 canaux
        y = np.zeros((self.batch_size * VOLUME_SLICES, 240, 240))  # Masques non redimensionnés
        Y = np.zeros((self.batch_size * VOLUME_SLICES, *self.dim, 4))  # Masques one-hot encodés

        # Generate data
        for c, patient_id in enumerate(Batch_ids):
            case_path = os.path.join(TRAIN_DATASET_PATH, patient_id)

            # Charger les modalités d'images
            flair = nib.load(os.path.join(case_path, f'{patient_id}_flair.nii')).get_fdata()
            t1ce = nib.load(os.path.join(case_path, f'{patient_id}_t1ce.nii')).get_fdata()
            t2 = nib.load(os.path.join(case_path, f'{patient_id}_t2.nii')).get_fdata()

            # Charger le masque de segmentation
            seg = nib.load(os.path.join(case_path, f'{patient_id}_seg.nii')).get_fdata()

            for j in range(VOLUME_SLICES):
                # Redimensionner les images
                X[j + VOLUME_SLICES * c, :, :, 0] = cv2.resize(flair[:, :, j + VOLUME_START_AT], self.dim)
                X[j + VOLUME_SLICES * c, :, :, 1] = cv2.resize(t1ce[:, :, j + VOLUME_START_AT], self.dim)
                X[j + VOLUME_SLICES * c, :, :, 2] = cv2.resize(t2[:, :, j + VOLUME_START_AT], self.dim)

                # Redimensionner les masques sans interpolation
                y[j + VOLUME_SLICES * c] = seg[:, :, j + VOLUME_START_AT]

        # Remplacer les valeurs 4 par 3 dans les masques
        y[y == 4] = 3

        # Encodage one-hot des masques
        mask = tf.one_hot(y.astype(np.int32), depth=4)

        # Redimensionner les masques one-hot encodés
        Y = tf.image.resize(mask, self.dim, method=tf.image.ResizeMethod.NEAREST_NEIGHBOR)

        # Normaliser les images
        X = (X - np.min(X)) / (np.max(X) - np.min(X) + 1e-7)

        return X, Y

# %%
training_generator = DataGenerator(train_patients)
valid_generator = DataGenerator(val_patients)
test_generator = DataGenerator(test_patients)

# %%
X_batch, Y_batch = training_generator[0]
print("X_batch shape:", X_batch.shape)
print("Y_batch shape:", Y_batch.shape)
print("X_batch min/max:", np.min(X_batch), np.max(X_batch))
print("Y_batch unique values:", np.unique(Y_batch))
# Out:
# X_batch shape: (100, 128, 128, 3)
# Y_batch shape: (100, 128, 128, 4)
# X_batch min/max: 0.0 0.9999999999700945
# Y_batch unique values: [0. 1.]

# %%
import matplotlib.pyplot as plt

# Define a function to display one slice and its segmentation
def display_slice_and_segmentation(flair, t1ce, t2, segmentation):
    """
    Affiche une tranche d'image FLAIR, T1CE, T2 et sa segmentation correspondante.
    """
    fig, axes = plt.subplots(1, 4, figsize=(16, 5))  # Ajout d'un sous-graphique pour T2

    # Afficher l'image FLAIR
    axes[0].imshow(flair, cmap='gray')
    axes[0].set_title('FLAIR')
    axes[0].axis('off')

    # Afficher l'image T1CE
    axes[1].imshow(t1ce, cmap='gray')
    axes[1].set_title('T1CE')
    axes[1].axis('off')

    # Afficher l'image T2
    axes[2].imshow(t2, cmap='gray')
    axes[2].set_title('T2')
    axes[2].axis('off')

    # Afficher la segmentation
    segmentation_colored = axes[3].imshow(segmentation, cmap='viridis', vmin=0, vmax=3)
    axes[3].set_title('Segmentation')
    axes[3].axis('off')

    # Ajouter une barre de couleur pour la segmentation
    cbar = fig.colorbar(segmentation_colored, ax=axes[3], orientation='vertical', shrink=0.8)
    cbar.set_ticks([0, 1, 2, 3])
    cbar.set_ticklabels(['Background', 'Necrotic', 'Edema', 'Enhancing'])

    plt.tight_layout()
    plt.show()


# Récupérer un batch depuis le générateur d'entraînement
X_batch, Y_batch = training_generator[0]  # Prendre le premier batch (index 0)

# Extraire les modalités FLAIR, T1CE, T2 et la segmentation à partir du batch
flair_batch = X_batch[:, :, :, 0]  # Modalité FLAIR
t1ce_batch = X_batch[:, :, :, 1]   # Modalité T1CE
t2_batch = X_batch[:, :, :, 2]     # Modalité T2
segmentation_batch = np.argmax(Y_batch, axis=-1)  # Convertir le masque one-hot en classes discrètes

# Sélectionner une tranche spécifique (par exemple, la 60e tranche)
slice_index = 60  # Index de la tranche à afficher
slice_flair = flair_batch[slice_index]
slice_t1ce = t1ce_batch[slice_index]
slice_t2 = t2_batch[slice_index]
slice_segmentation = segmentation_batch[slice_index]

# Afficher la tranche sélectionnée et sa segmentation
display_slice_and_segmentation(slice_flair, slice_t1ce, slice_t2, slice_segmentation)

# %% [markdown]
# # 7. Fonction de perte et métriques d'évaluation

# %% [markdown]
# ### **Fonction de Perte**
#
# Lors de l'entraînement d'un réseau de neurones convolutionnel (CNN), le choix d'une fonction de perte appropriée est essentiel pour évaluer avec précision les performances du modèle. Cette fonction compare les pixels prédits à la vérité terrain pour chaque patient, permettant ainsi au modèle d'ajuster ses poids afin de minimiser la perte et d'améliorer la précision des prédictions.
#
# Pour les problèmes de classification multi-classes, une fonction de perte couramment utilisée est l'**entropie croisée catégorielle** (*categorical cross-entropy*). Elle mesure la différence entre la distribution de probabilité prédite pour chaque pixel et les valeurs de vérité terrain encodées en *one-hot*.
#
# De plus, dans les modèles de segmentation, on utilise parfois la **fonction de perte de Dice** (*Dice loss*), qui met l'accent sur le chevauchement entre les segments prédits et réels. Cela permet d'améliorer encore la précision de la segmentation.
#
# L'utilisation de ces fonctions de perte garantit un apprentissage efficace du modèle et une segmentation précise des tumeurs cérébrales.

# %%
import tensorflow as tf
from keras import backend as K

def dice_coef(y_true, y_pred, smooth=1.0):
    class_num = 4
    total_loss = 0
    for i in range(class_num):
        y_true_f = tf.reshape(y_true[:, :, :, i], (-1,))
        y_pred_f = tf.reshape(y_pred[:, :, :, i], (-1,))

        intersection = tf.reduce_sum(y_true_f * y_pred_f)  # Replacing K.sum() with tf.reduce_sum()
        loss = (2. * intersection + smooth) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth)

        total_loss += loss

    return total_loss / class_num

# %% [markdown]
# ### Fonctions du Coefficient de Dice par Classe
#
# Ces fonctions calculent le coefficient de Dice pour des classes spécifiques de tumeurs dans les tâches de segmentation, permettant d’évaluer les performances du modèle dans la prédiction des différentes régions tumorales :
#
# - **dice_coef_necrotic** : Calcule le coefficient de Dice pour la région tumorale nécrotique (tissu mort). Il mesure l’intersection sur la somme des carrés des valeurs réelles et prédites pour la classe nécrotique.
#
# - **dice_coef_edema** : Calcule le coefficient de Dice pour la région tumorale œdémateuse (gonflement). Il mesure l’intersection sur la somme des carrés des valeurs réelles et prédites pour la classe de l’œdème.
#
# - **dice_coef_enhancing** : Calcule le coefficient de Dice pour la région tumorale rehaussée. Il mesure l’intersection sur la somme des carrés des valeurs réelles et prédites pour la classe de la tumeur rehaussée.

# %%
# Define per-class evaluation of Dice coefficient
def dice_coef_necrotic(y_true, y_pred, epsilon=1e-6):
    intersection = tf.reduce_sum(tf.abs(y_true[:, :, :, 1] * y_pred[:, :, :, 1]))
    return (2. * intersection) / (tf.reduce_sum(tf.square(y_true[:, :, :, 1])) + tf.reduce_sum(tf.square(y_pred[:, :, :, 1])) + epsilon)

def dice_coef_edema(y_true, y_pred, epsilon=1e-6):
    intersection = tf.reduce_sum(tf.abs(y_true[:, :, :, 2] * y_pred[:, :, :, 2]))
    return (2. * intersection) / (tf.reduce_sum(tf.square(y_true[:, :, :, 2])) + tf.reduce_sum(tf.square(y_pred[:, :, :, 2])) + epsilon)

def dice_coef_enhancing(y_true, y_pred, epsilon=1e-6):
    intersection = tf.reduce_sum(tf.abs(y_true[:, :, :, 3] * y_pred[:, :, :, 3]))
    return (2. * intersection) / (tf.reduce_sum(tf.square(y_true[:, :, :, 3])) + tf.reduce_sum(tf.square(y_pred[:, :, :, 3])) + epsilon)

# %% [markdown]
# ### Métriques d'Évaluation
#
# Pour surveiller efficacement les performances du modèle, nous utilisons plusieurs métriques d’évaluation :
#
# - **Exactitude (Accuracy)** : Mesure la proportion globale de pixels correctement classifiés. Toutefois, cette métrique peut être trompeuse sur des jeux de données déséquilibrés comme BraTS2020, où la classe de fond est surreprésentée.
# - **Intersection over Union (IoU)** : Évalue le chevauchement entre les segmentations prédites et celles de référence.
# - **Coefficient de Dice** : Mesure la similarité entre les segmentations prédites et celles de référence.
# - **Sensibilité (Recall ou Taux de Vrais Positifs)** : Mesure la proportion de pixels positifs dans la vérité terrain correctement prédits comme positifs.
# - **Précision (Valeur Prédictive Positive)** : Mesure la proportion de pixels prédits comme positifs qui sont réellement positifs.
# - **Spécificité (Taux de Vrais Négatifs)** : Mesure la proportion de pixels négatifs dans la vérité terrain correctement prédits comme négatifs.
#
# L'utilisation de ces métriques permet d’évaluer de manière plus complète les performances du modèle, en compensant les limites de l'exactitude seule sur des datasets déséquilibrés.

# %%
# Computing Precision
def precision(y_true, y_pred):
    true_positives = tf.reduce_sum(tf.round(tf.clip_by_value(y_true * y_pred, 0, 1)))
    predicted_positives = tf.reduce_sum(tf.round(tf.clip_by_value(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

# Computing Sensitivity (Recall)
def sensitivity(y_true, y_pred):
    true_positives = tf.reduce_sum(tf.round(tf.clip_by_value(y_true * y_pred, 0, 1)))
    possible_positives = tf.reduce_sum(tf.round(tf.clip_by_value(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())

# Computing Specificity
def specificity(y_true, y_pred):
    true_negatives = tf.reduce_sum(tf.round(tf.clip_by_value((1 - y_true) * (1 - y_pred), 0, 1)))
    possible_negatives = tf.reduce_sum(tf.round(tf.clip_by_value(1 - y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

# %% [markdown]
# # 8. Définition du Modèle de Segmentation
#
# ### U-Net
#
# Nous utiliserons l'architecture **U-Net**, un réseau de neurones convolutifs (CNN) spécialement conçu pour la segmentation d’images biomédicales. U-Net est particulièrement efficace pour segmenter des régions d’intérêt de petite taille et de formes complexes, comme les tumeurs dans les images IRM. Cette architecture a été introduite en 2015 par **Olaf Ronneberger, Philipp Fischer et Thomas Brox** dans leur article [U-Net: Convolutional Networks for Biomedical Image Segmentation](https://arxiv.org/abs/1505.04597).
#
# Le dataset **BraTS2020** étant composé d’images 3D, chaque image comprend plusieurs tranches 2D dans trois plans orthogonaux. Deux approches sont possibles : l'utilisation d'un **U-Net 2D** ou d'un **U-Net 3D**.
#
# - **U-Net 3D** : Mieux adapté à l’exploitation du contexte spatial 3D des images, ce qui réduit les faux positifs et les faux négatifs causés par l’analyse de tranches isolées. Cependant, cette approche nécessite davantage de ressources computationnelles et de mémoire.
# - **U-Net 2D** : Plus rapide et moins gourmand en mémoire, ce qui est avantageux pour le traitement de grands datasets ou lorsque les ressources informatiques sont limitées.
#
# Dans la pratique, il est pertinent de tester les deux architectures et de comparer leurs performances. Nous opterons pour une **implémentation du U-Net 2D**, en raison de son efficacité et de ses besoins en ressources réduits.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Dropout

def build_unet(input_shape, ker_init='he_normal', dropout=0.2):

    # Entrée du modèle
    inputs = Input(input_shape)

    # Encoder
    conv1 = Conv2D(32, 3, activation='relu', padding='same', kernel_initializer=ker_init)(inputs)
    conv1 = Conv2D(32, 3, activation='relu', padding='same', kernel_initializer=ker_init)(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer=ker_init)(pool1)
    conv2 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer=ker_init)(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(128, 3, activation='relu', padding='same', kernel_initializer=ker_init)(pool2)
    conv3 = Conv2D(128, 3, activation='relu', padding='same', kernel_initializer=ker_init)(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(256, 3, activation='relu', padding='same', kernel_initializer=ker_init)(pool3)
    conv4 = Conv2D(256, 3, activation='relu', padding='same', kernel_initializer=ker_init)(conv4)
    drop4 = Dropout(dropout)(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    # Bottleneck
    conv5 = Conv2D(512, 3, activation='relu', padding='same', kernel_initializer=ker_init)(pool4)
    conv5 = Conv2D(512, 3, activation='relu', padding='same', kernel_initializer=ker_init)(conv5)
    drop5 = Dropout(dropout)(conv5)

    # Decoder
    up6 = Conv2D(256, 2, activation='relu', padding='same', kernel_initializer=ker_init)(
        UpSampling2D(size=(2, 2))(drop5))
    merge6 = concatenate([drop4, up6], axis=3)
    conv6 = Conv2D(256, 3, activation='relu', padding='same', kernel_initializer=ker_init)(merge6)
    conv6 = Conv2D(256, 3, activation='relu', padding='same', kernel_initializer=ker_init)(conv6)

    up7 = Conv2D(128, 2, activation='relu', padding='same', kernel_initializer=ker_init)(
        UpSampling2D(size=(2, 2))(conv6))
    merge7 = concatenate([conv3, up7], axis=3)
    conv7 = Conv2D(128, 3, activation='relu', padding='same', kernel_initializer=ker_init)(merge7)
    conv7 = Conv2D(128, 3, activation='relu', padding='same', kernel_initializer=ker_init)(conv7)

    up8 = Conv2D(64, 2, activation='relu', padding='same', kernel_initializer=ker_init)(
        UpSampling2D(size=(2, 2))(conv7))
    merge8 = concatenate([conv2, up8], axis=3)
    conv8 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer=ker_init)(merge8)
    conv8 = Conv2D(64, 3, activation='relu', padding='same', kernel_initializer=ker_init)(conv8)

    up9 = Conv2D(32, 2, activation='relu', padding='same', kernel_initializer=ker_init)(
        UpSampling2D(size=(2, 2))(conv8))
    merge9 = concatenate([conv1, up9], axis=3)
    conv9 = Conv2D(32, 3, activation='relu', padding='same', kernel_initializer=ker_init)(merge9)
    conv9 = Conv2D(32, 3, activation='relu', padding='same', kernel_initializer=ker_init)(conv9)

    # Couche de sortie
    outputs = Conv2D(4, (1, 1), activation='softmax')(conv9)

    # Création du modèle
    model = Model(inputs=inputs, outputs=outputs)
    return model


# Paramètres globaux
IMG_SIZE = 128  # Taille des images après redimensionnement
INPUT_SHAPE = (IMG_SIZE, IMG_SIZE, 3)  # 3 canaux : FLAIR, T1CE, T2

# Construction du modèle
model = build_unet(input_shape=INPUT_SHAPE, ker_init='he_normal', dropout=0.2)
# model.summary()

# %%
model.compile(loss="categorical_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=0.001),
              metrics = ['accuracy',tf.keras.metrics.MeanIoU(num_classes=4), dice_coef, precision, sensitivity, specificity, dice_coef_necrotic, dice_coef_edema ,dice_coef_enhancing])

# %%
callbacks = [
    keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                                      patience=2, min_lr=0.000001, verbose=1),
    keras.callbacks.ModelCheckpoint(filepath='/content/unetOriginelDir/model_.{epoch:02d}-{val_loss:.6f}.weights.h5',
                                    verbose=1, save_best_only=True, save_weights_only=True),
    CSVLogger('/content/unetOriginelDir/training.log', separator=',', append=False)
]

# %% [markdown]
# # 9. Entraînement et Sauvegarde du Modèle
#
# Nous sommes maintenant prêts à entraîner notre réseau de neurones profond en utilisant la méthode `.fit()` de **Keras**. Nous intégrerons trois callbacks dans cette méthode, qui seront exécutés tout au long du processus d'entraînement, lequel durera **35 époques**.
# ```

# %%
! mkdir unetOriginelDir

# %%
K.clear_session()

history =  model.fit(training_generator,
                    epochs=35,
                    steps_per_epoch=len(train_patients),
                    callbacks= callbacks,
                    validation_data = valid_generator
                    )
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/35
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 659ms/step - accuracy: 0.9693 - dice_coef: 0.2538 - dice_coef_edema: 0.0884 - dice_coef_enhancing: 0.0335 - dice_coef_necrotic: 0.0541 - loss: 0.4353 - mean_io_u: 0.5662 - precision: 0.9611 - sensitivity: 0.9043 - specificity: 0.9948
# Epoch 1: val_loss improved from inf to 0.06699, saving model to /content/unetOriginelDir/model_.01-0.066992.weights.h5
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 293s 796ms/step - accuracy: 0.9693 - dice_coef: 0.2539 - dice_coef_edema: 0.0885 - dice_coef_enhancing: 0.0335 - dice_coef_necrotic: 0.0542 - loss: 0.4343 - mean_io_u: 0.5665 - precision: 0.9612 - sensitivity: 0.9045 - specificity: 0.9948 - val_accuracy: 0.9822 - val_dice_coef: 0.2930 - val_dice_coef_edema: 0.2140 - val_dice_coef_enhancing: 0.0657 - val_dice_coef_necrotic: 0.1261 - val_loss: 0.0670 - val_mean_io_u: 0.5315 - val_precision: 0.9844 - val_sensitivity: 0.9780 - val_specificity: 0.9948 - learning_rate: 0.0010
# Epoch 2/35
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 678ms/step - accuracy: 0.9826 - dice_coef: 0.2894 - dice_coef_edema: 0.1570 - dice_coef_enhancing: 0.0732 - dice_coef_necrotic: 0.1116 - loss: 0.0682 - mean_io_u: 0.6424 - precision: 0.9851 - sensitivity: 0.9809 - specificity: 0.9950
# Epoch 2: val_loss improved from 0.06699 to 0.06523, saving model to /content/unetOriginelDir/model_.02-0.065231.weights.h5
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 259s 750ms/step - accuracy: 0.9826 - dice_coef: 0.2894 - dice_coef_edema: 0.1570 - dice_coef_enhancing: 0.0733 - dice_coef_necrotic: 0.1116 - loss: 0.0682 - mean_io_u: 0.6424 - precision: 0.9851 - sensitivity: 0.9809 - specificity: 0.9950 - val_accuracy: 0.9817 - val_dice_coef: 0.2909 - val_dice_coef_edema: 0.2105 - val_dice_coef_enhancing: 0.0467 - val_dice_coef_necrotic: 0.0799 - val_loss: 0.0652 - val_mean_io_u: 0.4737 - val_precision: 0.9834 - val_sensitivity: 0.9813 - val_specificity: 0.9945 - learning_rate: 0.0010
# Epoch 3/35
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 701ms/step - accuracy: 0.9830 - dice_coef: 0.2948 - dice_coef_edema: 0.1980 - dice_coef_enhancing: 0.0818 - dice_coef_necrotic: 0.1121 - loss: 0.0750 - mean_io_u: 0.6835 - precision: 0.9857 - sensitivity: 0.9803 - specificity: 0.9953
# Epoch 3: val_loss did not improve from 0.06523
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 229s 775ms/step - accuracy: 0.9831 - dice_coef: 0.2948 - dice_coef_edema: 0.1979 - dice_coef_enhancing: 0.0818 - dice_coef_necrotic: 0.1121 - loss: 0.0750 - mean_io_u: 0.6834 - precision: 0.9857 - sensitivity: 0.9803 - specificity: 0.9953 - val_accuracy: 0.9821 - val_dice_coef: 0.3153 - val_dice_coef_edema: 0.1569 - val_dice_coef_enhancing: 0.1156 - val_dice_coef_necrotic: 0.1387 - val_loss: 0.0752 - val_mean_io_u: 0.7098 - val_precision: 0.9841 - val_sensitivity: 0.9817 - val_specificity: 0.9947 - learning_rate: 0.0010
# Epoch 4/35
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 695ms/step - accuracy: 0.9834 - dice_coef: 0.2998 - dice_coef_edema: 0.2058 - dice_coef_enhancing: 0.1088 - dice_coef_necrotic: 0.1254 - loss: 0.0719 - mean_io_u: 0.6506 - precision: 0.9862 - sensitivity: 0.9810 - specificity: 0.9954
# Epoch 4: val_loss improved from 0.06523 to 0.05324, saving model to /content/unetOriginelDir/model_.04-0.053245.weights.h5
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 227s 769ms/step - accuracy: 0.9834 - dice_coef: 0.2998 - dice_coef_edema: 0.2059 - dice_coef_enhancing: 0.1088 - dice_coef_necrotic: 0.1255 - loss: 0.0718 - mean_io_u: 0.6508 - precision: 0.9862 - sensitivity: 0.9810 - specificity: 0.9954 - val_accuracy: 0.9840 - val_dice_coef: 0.3543 - val_dice_coef_edema: 0.3648 - val_dice_coef_enhancing: 0.2649 - val_dice_coef_necrotic: 0.2291 - val_loss: 0.0532 - val_mean_io_u: 0.7338 - val_precision: 0.9930 - val_sensitivity: 0.9758 - val_specificity: 0.9977 - learning_rate: 0.0010
# Epoch 5/35
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 649ms/step - accuracy: 0.9854 - dice_coef: 0.3474 - dice_coef_edema: 0.3128 - dice_coef_enhancing: 0.2114 - dice_coef_necrotic: 0.2014 - loss: 0.0519 - mean_io_u: 0.7218 - precision: 0.9901 - sensitivity: 0.9811 - specificity: 0.9967
# Epoch 5: val_loss improved from 0.05324 to 0.04508, saving model to /content/unetOriginelDir/model_.05-0.045075.weights.h5
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 215s 726ms/step - accuracy: 0.9854 - dice_coef: 0.3474 - dice_coef_edema: 0.3128 - dice_coef_enhancing: 0.2114 - dice_coef_necrotic: 0.2014 - loss: 0.0519 - mean_io_u: 0.7218 - precision: 0.9901 - sensitivity: 0.9811 - specificity: 0.9967 - val_accuracy: 0.9851 - val_dice_coef: 0.3722 - val_dice_coef_edema: 0.3710 - val_dice_coef_enhancing: 0.1764 - val_dice_coef_necrotic: 0.2240 - val_loss: 0.0451 - val_mean_io_u: 0.7727 - val_precision: 0.9886 - val_sensitivity: 0.9820 - val_specificity: 0.9962 - learning_rate: 0.0010
# Epoch 6/35
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 668ms/step - accuracy: 0.9854 - dice_coef: 0.3508 - dice_coef_edema: 0.3054 - dice_coef_enhancing: 0.2202 - dice_coef_necrotic: 0.1971 - loss: 0.0488 - mean_io_u: 0.7819 - precision: 0.9905 - sensitivity: 0.9814 - specificity: 0.9969
# Epoch 6: val_loss improved from 0.04508 to 0.03649, saving model to /content/unetOriginelDir/model_.06-0.036492.weights.h5
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 219s 742ms/step - accuracy: 0.9854 - dice_coef: 0.3508 - dice_coef_edema: 0.3056 - dice_coef_enhancing: 0.2203 - dice_coef_necrotic: 0.1972 - loss: 0.0488 - mean_io_u: 0.7820 - precision: 0.9905 - sensitivity: 0.9814 - specificity: 0.9969 - val_accuracy: 0.9883 - val_dice_coef: 0.4143 - val_dice_coef_edema: 0.5303 - val_dice_coef_enhancing: 0.3367 - val_dice_coef_necrotic: 0.2606 - val_loss: 0.0365 - val_mean_io_u: 0.8193 - val_precision: 0.9929 - val_sensitivity: 0.9832 - val_specificity: 0.9977 - learning_rate: 0.0010
# Epoch 7/35
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 673ms/step - accuracy: 0.9866 - dice_coef: 0.3790 - dice_coef_edema: 0.3751 - dice_coef_enhancing: 0.2971 - dice_coef_necrotic: 0.2313 - loss: 0.0435 - mean_io_u: 0.7669 - precision: 0.9919 - sensitivity: 0.9823 - specificity: 0.9973
# Epoch 7: val_loss did not improve from 0.03649
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 263s 745ms/step - accuracy: 0.9866 - dice_coef: 0.3790 - dice_coef_edema: 0.3751 - dice_coef_enhancing: 0.2970 - dice_coef_necrotic: 0.2314 - loss: 0.0435 - mean_io_u: 0.7669 - precision: 0.9919 - sensitivity: 0.9823 - specificity: 0.9973 - val_accuracy: 0.9880 - val_dice_coef: 0.3976 - val_dice_coef_edema: 0.5357 - val_dice_coef_enhancing: 0.2944 - val_dice_coef_necrotic: 0.2682 - val_loss: 0.0392 - val_mean_io_u: 0.8121 - val_precision: 0.9936 - val_sensitivity: 0.9818 - val_specificity: 0.9979 - learning_rate: 0.0010
# Epoch 8/35
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 648ms/step - accuracy: 0.9876 - dice_coef: 0.3955 - dice_coef_edema: 0.4112 - dice_coef_enhancing: 0.3059 - dice_coef_necrotic: 0.2773 - loss: 0.0374 - mean_io_u: 0.7884 - precision: 0.9927 - sensitivity: 0.9832 - specificity: 0.9976
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 8: val_loss did not improve from 0.03649
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 255s 722ms/step - accuracy: 0.9876 - dice_coef: 0.3955 - dice_coef_edema: 0.4112 - dice_coef_enhancing: 0.3059 - dice_coef_necrotic: 0.2772 - loss: 0.0374 - mean_io_u: 0.7884 - precision: 0.9927 - sensitivity: 0.9832 - specificity: 0.9976 - val_accuracy: 0.9849 - val_dice_coef: 0.3534 - val_dice_coef_edema: 0.4428 - val_dice_coef_enhancing: 0.0987 - val_dice_coef_necrotic: 0.1465 - val_loss: 0.0464 - val_mean_io_u: 0.8066 - val_precision: 0.9868 - val_sensitivity: 0.9837 - val_specificity: 0.9956 - learning_rate: 0.0010
# Epoch 9/35
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 678ms/step - accuracy: 0.9886 - dice_coef: 0.3847 - dice_coef_edema: 0.4241 - dice_coef_enhancing: 0.2539 - dice_coef_necrotic: 0.2345 - loss: 0.0359 - mean_io_u: 0.8118 - precision: 0.9922 - sensitivity: 0.9858 - specificity: 0.9974
# Epoch 9: val_loss improved from 0.03649 to 0.03419, saving model to /content/unetOriginelDir/model_.09-0.034192.weights.h5
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 222s 753ms/step - accuracy: 0.9886 - dice_coef: 0.3848 - dice_coef_edema: 0.4243 - dice_coef_enhancing: 0.2541 - dice_coef_necrotic: 0.2346 - loss: 0.0359 - mean_io_u: 0.8118 - precision: 0.9922 - sensitivity: 0.9858 - specificity: 0.9974 - val_accuracy: 0.9883 - val_dice_coef: 0.4321 - val_dice_coef_edema: 0.5463 - val_dice_coef_enhancing: 0.4117 - val_dice_coef_necrotic: 0.3068 - val_loss: 0.0342 - val_mean_io_u: 0.7993 - val_precision: 0.9957 - val_sensitivity: 0.9806 - val_specificity: 0.9986 - learning_rate: 2.0000e-04
# Epoch 10/35
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 648ms/step - accuracy: 0.9894 - dice_coef: 0.4271 - dice_coef_edema: 0.4768 - dice_coef_enhancing: 0.3687 - dice_coef_necrotic: 0.3110 - loss: 0.0302 - mean_io_u: 0.8070 - precision: 0.9945 - sensitivity: 0.9850 - specificity: 0.9982
# Epoch 10: val_loss improved from 0.03419 to 0.03131, saving model to /content/unetOriginelDir/model_.10-0.031307.weights.h5
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 233s 789ms/step - accuracy: 0.9894 - dice_coef: 0.4272 - dice_coef_edema: 0.4769 - dice_coef_enhancing: 0.3687 - dice_coef_necrotic: 0.3109 - loss: 0.0302 - mean_io_u: 0.8070 - precision: 0.9945 - sensitivity: 0.9850 - specificity: 0.9982 - val_accuracy: 0.9893 - val_dice_coef: 0.4531 - val_dice_coef_edema: 0.5931 - val_dice_coef_enhancing: 0.3936 - val_dice_coef_necrotic: 0.3225 - val_loss: 0.0313 - val_mean_io_u: 0.8037 - val_precision: 0.9940 - val_sensitivity: 0.9846 - val_specificity: 0.9980 - learning_rate: 2.0000e-04
# Epoch 11/35
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 678ms/step - accuracy: 0.9888 - dice_coef: 0.4420 - dice_coef_edema: 0.5128 - dice_coef_enhancing: 0.3850 - dice_coef_necrotic: 0.3264 - loss: 0.0311 - mean_io_u: 0.8046 - precision: 0.9938 - sensitivity: 0.9850 - specificity: 0.9979
# Epoch 11: val_loss improved from 0.03131 to 0.02932, saving model to /content/unetOriginelDir/model_.11-0.029323.weights.h5
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 221s 748ms/step - accuracy: 0.9888 - dice_coef: 0.4420 - dice_coef_edema: 0.5128 - dice_coef_enhancing: 0.3850 - dice_coef_necrotic: 0.3263 - loss: 0.0311 - mean_io_u: 0.8046 - precision: 0.9938 - sensitivity: 0.9850 - specificity: 0.9979 - val_accuracy: 0.9901 - val_dice_coef: 0.4737 - val_dice_coef_edema: 0.6434 - val_dice_coef_enhancing: 0.3846 - val_dice_coef_necrotic: 0.3223 - val_loss: 0.0293 - val_mean_io_u: 0.8149 - val_precision: 0.9930 - val_sensitivity: 0.9878 - val_specificity: 0.9977 - learning_rate: 2.0000e-04
# Epoch 12/35
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 661ms/step - accuracy: 0.9895 - dice_coef: 0.4652 - dice_coef_edema: 0.5499 - dice_coef_enhancing: 0.4306 - dice_coef_necrotic: 0.3413 - loss: 0.0290 - mean_io_u: 0.8120 - precision: 0.9936 - sensitivity: 0.9864 - specificity: 0.9979
# Epoch 12: val_loss did not improve from 0.02932
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 257s 731ms/step - accuracy: 0.9895 - dice_coef: 0.4652 - dice_coef_edema: 0.5499 - dice_coef_enhancing: 0.4306 - dice_coef_necrotic: 0.3413 - loss: 0.0290 - mean_io_u: 0.8120 - precision: 0.9936 - sensitivity: 0.9864 - specificity: 0.9979 - val_accuracy: 0.9894 - val_dice_coef: 0.4655 - val_dice_coef_edema: 0.6615 - val_dice_coef_enhancing: 0.3673 - val_dice_coef_necrotic: 0.3477 - val_loss: 0.0308 - val_mean_io_u: 0.8140 - val_precision: 0.9928 - val_sensitivity: 0.9869 - val_specificity: 0.9976 - learning_rate: 2.0000e-04
# Epoch 13/35
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 638ms/step - accuracy: 0.9900 - dice_coef: 0.4604 - dice_coef_edema: 0.5671 - dice_coef_enhancing: 0.4125 - dice_coef_necrotic: 0.3211 - loss: 0.0286 - mean_io_u: 0.8172 - precision: 0.9937 - sensitivity: 0.9871 - specificity: 0.9979
# Epoch 13: val_loss improved from 0.02932 to 0.02841, saving model to /content/unetOriginelDir/model_.13-0.028408.weights.h5
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 210s 709ms/step - accuracy: 0.9900 - dice_coef: 0.4604 - dice_coef_edema: 0.5671 - dice_coef_enhancing: 0.4126 - dice_coef_necrotic: 0.3212 - loss: 0.0286 - mean_io_u: 0.8172 - precision: 0.9937 - sensitivity: 0.9871 - specificity: 0.9979 - val_accuracy: 0.9901 - val_dice_coef: 0.4834 - val_dice_coef_edema: 0.6213 - val_dice_coef_enhancing: 0.4324 - val_dice_coef_necrotic: 0.3626 - val_loss: 0.0284 - val_mean_io_u: 0.8129 - val_precision: 0.9940 - val_sensitivity: 0.9865 - val_specificity: 0.9980 - learning_rate: 2.0000e-04
# Epoch 14/35
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 667ms/step - accuracy: 0.9903 - dice_coef: 0.4712 - dice_coef_edema: 0.5551 - dice_coef_enhancing: 0.4422 - dice_coef_necrotic: 0.3526 - loss: 0.0269 - mean_io_u: 0.8146 - precision: 0.9941 - sensitivity: 0.9873 - specificity: 0.9980
# Epoch 14: val_loss did not improve from 0.02841
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 271s 743ms/step - accuracy: 0.9903 - dice_coef: 0.4711 - dice_coef_edema: 0.5551 - dice_coef_enhancing: 0.4422 - dice_coef_necrotic: 0.3526 - loss: 0.0269 - mean_io_u: 0.8146 - precision: 0.9941 - sensitivity: 0.9873 - specificity: 0.9980 - val_accuracy: 0.9904 - val_dice_coef: 0.4861 - val_dice_coef_edema: 0.5986 - val_dice_coef_enhancing: 0.4748 - val_dice_coef_necrotic: 0.3510 - val_loss: 0.0287 - val_mean_io_u: 0.8207 - val_precision: 0.9940 - val_sensitivity: 0.9868 - val_specificity: 0.9980 - learning_rate: 2.0000e-04
# Epoch 15/35
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 685ms/step - accuracy: 0.9909 - dice_coef: 0.4702 - dice_coef_edema: 0.5561 - dice_coef_enhancing: 0.4334 - dice_coef_necrotic: 0.3398 - loss: 0.0253 - mean_io_u: 0.8208 - precision: 0.9943 - sensitivity: 0.9882 - specificity: 0.9981
# Epoch 15: val_loss improved from 0.02841 to 0.02760, saving model to /content/unetOriginelDir/model_.15-0.027600.weights.h5
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 267s 760ms/step - accuracy: 0.9909 - dice_coef: 0.4702 - dice_coef_edema: 0.5562 - dice_coef_enhancing: 0.4335 - dice_coef_necrotic: 0.3398 - loss: 0.0253 - mean_io_u: 0.8208 - precision: 0.9943 - sensitivity: 0.9882 - specificity: 0.9981 - val_accuracy: 0.9903 - val_dice_coef: 0.4993 - val_dice_coef_edema: 0.6432 - val_dice_coef_enhancing: 0.4974 - val_dice_coef_necrotic: 0.3941 - val_loss: 0.0276 - val_mean_io_u: 0.8107 - val_precision: 0.9942 - val_sensitivity: 0.9867 - val_specificity: 0.9981 - learning_rate: 2.0000e-04
# Epoch 16/35
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 642ms/step - accuracy: 0.9905 - dice_coef: 0.4854 - dice_coef_edema: 0.5654 - dice_coef_enhancing: 0.4528 - dice_coef_necrotic: 0.3944 - loss: 0.0267 - mean_io_u: 0.8195 - precision: 0.9941 - sensitivity: 0.9875 - specificity: 0.9980
# Epoch 16: val_loss did not improve from 0.02760
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 231s 782ms/step - accuracy: 0.9905 - dice_coef: 0.4854 - dice_coef_edema: 0.5654 - dice_coef_enhancing: 0.4529 - dice_coef_necrotic: 0.3944 - loss: 0.0267 - mean_io_u: 0.8195 - precision: 0.9941 - sensitivity: 0.9875 - specificity: 0.9980 - val_accuracy: 0.9888 - val_dice_coef: 0.4864 - val_dice_coef_edema: 0.6239 - val_dice_coef_enhancing: 0.4932 - val_dice_coef_necrotic: 0.3847 - val_loss: 0.0305 - val_mean_io_u: 0.8089 - val_precision: 0.9936 - val_sensitivity: 0.9850 - val_specificity: 0.9979 - learning_rate: 2.0000e-04
# Epoch 17/35
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 672ms/step - accuracy: 0.9905 - dice_coef: 0.4762 - dice_coef_edema: 0.5820 - dice_coef_enhancing: 0.4175 - dice_coef_necrotic: 0.3651 - loss: 0.0268 - mean_io_u: 0.8144 - precision: 0.9938 - sensitivity: 0.9878 - specificity: 0.9980
# Epoch 17: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 17: val_loss did not improve from 0.02760
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 221s 748ms/step - accuracy: 0.9905 - dice_coef: 0.4762 - dice_coef_edema: 0.5820 - dice_coef_enhancing: 0.4177 - dice_coef_necrotic: 0.3651 - loss: 0.0268 - mean_io_u: 0.8144 - precision: 0.9938 - sensitivity: 0.9878 - specificity: 0.9980 - val_accuracy: 0.9906 - val_dice_coef: 0.5004 - val_dice_coef_edema: 0.6269 - val_dice_coef_enhancing: 0.4508 - val_dice_coef_necrotic: 0.3698 - val_loss: 0.0304 - val_mean_io_u: 0.8244 - val_precision: 0.9930 - val_sensitivity: 0.9882 - val_specificity: 0.9977 - learning_rate: 2.0000e-04
# Epoch 18/35
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 648ms/step - accuracy: 0.9914 - dice_coef: 0.4953 - dice_coef_edema: 0.5752 - dice_coef_enhancing: 0.4834 - dice_coef_necrotic: 0.3996 - loss: 0.0242 - mean_io_u: 0.8198 - precision: 0.9944 - sensitivity: 0.9889 - specificity: 0.9981
# Epoch 18: val_loss improved from 0.02760 to 0.02500, saving model to /content/unetOriginelDir/model_.18-0.025004.weights.h5
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 212s 718ms/step - accuracy: 0.9914 - dice_coef: 0.4953 - dice_coef_edema: 0.5752 - dice_coef_enhancing: 0.4835 - dice_coef_necrotic: 0.3996 - loss: 0.0242 - mean_io_u: 0.8198 - precision: 0.9944 - sensitivity: 0.9889 - specificity: 0.9981 - val_accuracy: 0.9916 - val_dice_coef: 0.5219 - val_dice_coef_edema: 0.6916 - val_dice_coef_enhancing: 0.4943 - val_dice_coef_necrotic: 0.3934 - val_loss: 0.0250 - val_mean_io_u: 0.8217 - val_precision: 0.9938 - val_sensitivity: 0.9897 - val_specificity: 0.9979 - learning_rate: 4.0000e-05
# Epoch 19/35
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 667ms/step - accuracy: 0.9915 - dice_coef: 0.5122 - dice_coef_edema: 0.6114 - dice_coef_enhancing: 0.5111 - dice_coef_necrotic: 0.3969 - loss: 0.0232 - mean_io_u: 0.8250 - precision: 0.9941 - sensitivity: 0.9894 - specificity: 0.9981
# Epoch 19: val_loss improved from 0.02500 to 0.02491, saving model to /content/unetOriginelDir/model_.19-0.024912.weights.h5
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 220s 743ms/step - accuracy: 0.9915 - dice_coef: 0.5122 - dice_coef_edema: 0.6115 - dice_coef_enhancing: 0.5111 - dice_coef_necrotic: 0.3969 - loss: 0.0232 - mean_io_u: 0.8250 - precision: 0.9941 - sensitivity: 0.9894 - specificity: 0.9981 - val_accuracy: 0.9916 - val_dice_coef: 0.5265 - val_dice_coef_edema: 0.6930 - val_dice_coef_enhancing: 0.5072 - val_dice_coef_necrotic: 0.4101 - val_loss: 0.0249 - val_mean_io_u: 0.8233 - val_precision: 0.9940 - val_sensitivity: 0.9895 - val_specificity: 0.9980 - learning_rate: 4.0000e-05
# Epoch 20/35
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 665ms/step - accuracy: 0.9919 - dice_coef: 0.5192 - dice_coef_edema: 0.6340 - dice_coef_enhancing: 0.5072 - dice_coef_necrotic: 0.4157 - loss: 0.0222 - mean_io_u: 0.8253 - precision: 0.9943 - sensitivity: 0.9898 - specificity: 0.9981
# Epoch 20: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
#
# Epoch 20: val_loss did not improve from 0.02491
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 218s 737ms/step - accuracy: 0.9919 - dice_coef: 0.5192 - dice_coef_edema: 0.6339 - dice_coef_enhancing: 0.5072 - dice_coef_necrotic: 0.4156 - loss: 0.0222 - mean_io_u: 0.8253 - precision: 0.9943 - sensitivity: 0.9898 - specificity: 0.9981 - val_accuracy: 0.9917 - val_dice_coef: 0.5275 - val_dice_coef_edema: 0.6785 - val_dice_coef_enhancing: 0.5271 - val_dice_coef_necrotic: 0.3937 - val_loss: 0.0252 - val_mean_io_u: 0.8256 - val_precision: 0.9941 - val_sensitivity: 0.9894 - val_specificity: 0.9980 - learning_rate: 4.0000e-05
# Epoch 21/35
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 635ms/step - accuracy: 0.9910 - dice_coef: 0.5172 - dice_coef_edema: 0.6174 - dice_coef_enhancing: 0.5177 - dice_coef_necrotic: 0.4126 - loss: 0.0241 - mean_io_u: 0.8238 - precision: 0.9942 - sensitivity: 0.9883 - specificity: 0.9981
# Epoch 21: val_loss improved from 0.02491 to 0.02469, saving model to /content/unetOriginelDir/model_.21-0.024688.weights.h5
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 210s 709ms/step - accuracy: 0.9910 - dice_coef: 0.5172 - dice_coef_edema: 0.6175 - dice_coef_enhancing: 0.5178 - dice_coef_necrotic: 0.4126 - loss: 0.0241 - mean_io_u: 0.8238 - precision: 0.9942 - sensitivity: 0.9883 - specificity: 0.9981 - val_accuracy: 0.9917 - val_dice_coef: 0.5292 - val_dice_coef_edema: 0.6908 - val_dice_coef_enhancing: 0.5232 - val_dice_coef_necrotic: 0.4053 - val_loss: 0.0247 - val_mean_io_u: 0.8246 - val_precision: 0.9941 - val_sensitivity: 0.9896 - val_specificity: 0.9981 - learning_rate: 8.0000e-06
# Epoch 22/35
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 674ms/step - accuracy: 0.9923 - dice_coef: 0.5277 - dice_coef_edema: 0.6426 - dice_coef_enhancing: 0.5427 - dice_coef_necrotic: 0.4248 - loss: 0.0211 - mean_io_u: 0.8244 - precision: 0.9948 - sensitivity: 0.9903 - specificity: 0.9983
# Epoch 22: val_loss did not improve from 0.02469
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 222s 749ms/step - accuracy: 0.9923 - dice_coef: 0.5277 - dice_coef_edema: 0.6426 - dice_coef_enhancing: 0.5427 - dice_coef_necrotic: 0.4247 - loss: 0.0211 - mean_io_u: 0.8244 - precision: 0.9948 - sensitivity: 0.9903 - specificity: 0.9983 - val_accuracy: 0.9917 - val_dice_coef: 0.5301 - val_dice_coef_edema: 0.6909 - val_dice_coef_enhancing: 0.5268 - val_dice_coef_necrotic: 0.4105 - val_loss: 0.0248 - val_mean_io_u: 0.8252 - val_precision: 0.9941 - val_sensitivity: 0.9895 - val_specificity: 0.9981 - learning_rate: 8.0000e-06
# Epoch 23/35
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 655ms/step - accuracy: 0.9920 - dice_coef: 0.5139 - dice_coef_edema: 0.6169 - dice_coef_enhancing: 0.4976 - dice_coef_necrotic: 0.4142 - loss: 0.0220 - mean_io_u: 0.8264 - precision: 0.9946 - sensitivity: 0.9898 - specificity: 0.9982
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
#
# Epoch 23: val_loss improved from 0.02469 to 0.02463, saving model to /content/unetOriginelDir/model_.23-0.024629.weights.h5
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 215s 727ms/step - accuracy: 0.9920 - dice_coef: 0.5139 - dice_coef_edema: 0.6170 - dice_coef_enhancing: 0.4977 - dice_coef_necrotic: 0.4142 - loss: 0.0220 - mean_io_u: 0.8264 - precision: 0.9946 - sensitivity: 0.9898 - specificity: 0.9982 - val_accuracy: 0.9918 - val_dice_coef: 0.5324 - val_dice_coef_edema: 0.6937 - val_dice_coef_enhancing: 0.5224 - val_dice_coef_necrotic: 0.4085 - val_loss: 0.0246 - val_mean_io_u: 0.8270 - val_precision: 0.9940 - val_sensitivity: 0.9898 - val_specificity: 0.9980 - learning_rate: 8.0000e-06
# Epoch 24/35
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 658ms/step - accuracy: 0.9917 - dice_coef: 0.5279 - dice_coef_edema: 0.6552 - dice_coef_enhancing: 0.5294 - dice_coef_necrotic: 0.4103 - loss: 0.0226 - mean_io_u: 0.8277 - precision: 0.9942 - sensitivity: 0.9896 - specificity: 0.9981
# Epoch 24: val_loss improved from 0.02463 to 0.02462, saving model to /content/unetOriginelDir/model_.24-0.024619.weights.h5
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 217s 734ms/step - accuracy: 0.9917 - dice_coef: 0.5279 - dice_coef_edema: 0.6552 - dice_coef_enhancing: 0.5294 - dice_coef_necrotic: 0.4103 - loss: 0.0226 - mean_io_u: 0.8277 - precision: 0.9942 - sensitivity: 0.9896 - specificity: 0.9981 - val_accuracy: 0.9918 - val_dice_coef: 0.5327 - val_dice_coef_edema: 0.6942 - val_dice_coef_enhancing: 0.5222 - val_dice_coef_necrotic: 0.4089 - val_loss: 0.0246 - val_mean_io_u: 0.8271 - val_precision: 0.9940 - val_sensitivity: 0.9898 - val_specificity: 0.9980 - learning_rate: 1.6000e-06
# Epoch 25/35
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 666ms/step - accuracy: 0.9917 - dice_coef: 0.5216 - dice_coef_edema: 0.6476 - dice_coef_enhancing: 0.4914 - dice_coef_necrotic: 0.4161 - loss: 0.0224 - mean_io_u: 0.8278 - precision: 0.9942 - sensitivity: 0.9896 - specificity: 0.9981
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 25: val_loss improved from 0.02462 to 0.02461, saving model to /content/unetOriginelDir/model_.25-0.024609.weights.h5
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 264s 742ms/step - accuracy: 0.9917 - dice_coef: 0.5216 - dice_coef_edema: 0.6475 - dice_coef_enhancing: 0.4916 - dice_coef_necrotic: 0.4161 - loss: 0.0224 - mean_io_u: 0.8278 - precision: 0.9942 - sensitivity: 0.9896 - specificity: 0.9981 - val_accuracy: 0.9918 - val_dice_coef: 0.5329 - val_dice_coef_edema: 0.6945 - val_dice_coef_enhancing: 0.5220 - val_dice_coef_necrotic: 0.4090 - val_loss: 0.0246 - val_mean_io_u: 0.8273 - val_precision: 0.9940 - val_sensitivity: 0.9898 - val_specificity: 0.9980 - learning_rate: 1.6000e-06
# Epoch 26/35
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 657ms/step - accuracy: 0.9921 - dice_coef: 0.5233 - dice_coef_edema: 0.6315 - dice_coef_enhancing: 0.5260 - dice_coef_necrotic: 0.4227 - loss: 0.0215 - mean_io_u: 0.8285 - precision: 0.9945 - sensitivity: 0.9901 - specificity: 0.9982
# Epoch 26: val_loss improved from 0.02461 to 0.02461, saving model to /content/unetOriginelDir/model_.26-0.024609.weights.h5
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 216s 730ms/step - accuracy: 0.9921 - dice_coef: 0.5233 - dice_coef_edema: 0.6315 - dice_coef_enhancing: 0.5260 - dice_coef_necrotic: 0.4227 - loss: 0.0215 - mean_io_u: 0.8285 - precision: 0.9945 - sensitivity: 0.9901 - specificity: 0.9982 - val_accuracy: 0.9918 - val_dice_coef: 0.5331 - val_dice_coef_edema: 0.6946 - val_dice_coef_enhancing: 0.5220 - val_dice_coef_necrotic: 0.4090 - val_loss: 0.0246 - val_mean_io_u: 0.8273 - val_precision: 0.9940 - val_sensitivity: 0.9898 - val_specificity: 0.9980 - learning_rate: 1.0000e-06
# Epoch 27/35
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 664ms/step - accuracy: 0.9918 - dice_coef: 0.5313 - dice_coef_edema: 0.6431 - dice_coef_enhancing: 0.5368 - dice_coef_necrotic: 0.4257 - loss: 0.0221 - mean_io_u: 0.8281 - precision: 0.9944 - sensitivity: 0.9897 - specificity: 0.9981
# Epoch 27: val_loss improved from 0.02461 to 0.02460, saving model to /content/unetOriginelDir/model_.27-0.024596.weights.h5
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 265s 740ms/step - accuracy: 0.9918 - dice_coef: 0.5313 - dice_coef_edema: 0.6431 - dice_coef_enhancing: 0.5367 - dice_coef_necrotic: 0.4257 - loss: 0.0221 - mean_io_u: 0.8281 - precision: 0.9944 - sensitivity: 0.9897 - specificity: 0.9981 - val_accuracy: 0.9918 - val_dice_coef: 0.5331 - val_dice_coef_edema: 0.6949 - val_dice_coef_enhancing: 0.5224 - val_dice_coef_necrotic: 0.4091 - val_loss: 0.0246 - val_mean_io_u: 0.8272 - val_precision: 0.9940 - val_sensitivity: 0.9898 - val_specificity: 0.9980 - learning_rate: 1.0000e-06
# Epoch 28/35
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 665ms/step - accuracy: 0.9919 - dice_coef: 0.5246 - dice_coef_edema: 0.6369 - dice_coef_enhancing: 0.5313 - dice_coef_necrotic: 0.4111 - loss: 0.0222 - mean_io_u: 0.8277 - precision: 0.9944 - sensitivity: 0.9899 - specificity: 0.9981
# Epoch 28: val_loss did not improve from 0.02460
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 218s 736ms/step - accuracy: 0.9919 - dice_coef: 0.5246 - dice_coef_edema: 0.6369 - dice_coef_enhancing: 0.5313 - dice_coef_necrotic: 0.4112 - loss: 0.0222 - mean_io_u: 0.8277 - precision: 0.9944 - sensitivity: 0.9899 - specificity: 0.9981 - val_accuracy: 0.9918 - val_dice_coef: 0.5332 - val_dice_coef_edema: 0.6947 - val_dice_coef_enhancing: 0.5233 - val_dice_coef_necrotic: 0.4096 - val_loss: 0.0246 - val_mean_io_u: 0.8272 - val_precision: 0.9940 - val_sensitivity: 0.9898 - val_specificity: 0.9980 - learning_rate: 1.0000e-06
# Epoch 29/35
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 636ms/step - accuracy: 0.9923 - dice_coef: 0.5203 - dice_coef_edema: 0.6185 - dice_coef_enhancing: 0.5155 - dice_coef_necrotic: 0.4189 - loss: 0.0211 - mean_io_u: 0.8274 - precision: 0.9947 - sensitivity: 0.9903 - specificity: 0.9982
# Epoch 29: val_loss improved from 0.02460 to 0.02459, saving model to /content/unetOriginelDir/model_.29-0.024593.weights.h5
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 254s 708ms/step - accuracy: 0.9923 - dice_coef: 0.5204 - dice_coef_edema: 0.6186 - dice_coef_enhancing: 0.5155 - dice_coef_necrotic: 0.4189 - loss: 0.0211 - mean_io_u: 0.8274 - precision: 0.9947 - sensitivity: 0.9903 - specificity: 0.9982 - val_accuracy: 0.9918 - val_dice_coef: 0.5334 - val_dice_coef_edema: 0.6950 - val_dice_coef_enhancing: 0.5229 - val_dice_coef_necrotic: 0.4097 - val_loss: 0.0246 - val_mean_io_u: 0.8273 - val_precision: 0.9940 - val_sensitivity: 0.9898 - val_specificity: 0.9980 - learning_rate: 1.0000e-06
# Epoch 30/35
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 671ms/step - accuracy: 0.9923 - dice_coef: 0.5265 - dice_coef_edema: 0.6185 - dice_coef_enhancing: 0.5407 - dice_coef_necrotic: 0.4360 - loss: 0.0208 - mean_io_u: 0.8262 - precision: 0.9947 - sensitivity: 0.9903 - specificity: 0.9983
# Epoch 30: val_loss improved from 0.02459 to 0.02459, saving model to /content/unetOriginelDir/model_.30-0.024588.weights.h5
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 273s 746ms/step - accuracy: 0.9923 - dice_coef: 0.5265 - dice_coef_edema: 0.6186 - dice_coef_enhancing: 0.5407 - dice_coef_necrotic: 0.4359 - loss: 0.0208 - mean_io_u: 0.8262 - precision: 0.9947 - sensitivity: 0.9903 - specificity: 0.9983 - val_accuracy: 0.9918 - val_dice_coef: 0.5335 - val_dice_coef_edema: 0.6952 - val_dice_coef_enhancing: 0.5231 - val_dice_coef_necrotic: 0.4097 - val_loss: 0.0246 - val_mean_io_u: 0.8273 - val_precision: 0.9940 - val_sensitivity: 0.9898 - val_specificity: 0.9980 - learning_rate: 1.0000e-06
# Epoch 31/35
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 673ms/step - accuracy: 0.9923 - dice_coef: 0.5319 - dice_coef_edema: 0.6491 - dice_coef_enhancing: 0.5456 - dice_coef_necrotic: 0.4215 - loss: 0.0210 - mean_io_u: 0.8283 - precision: 0.9946 - sensitivity: 0.9903 - specificity: 0.9982
# Epoch 31: val_loss improved from 0.02459 to 0.02457, saving model to /content/unetOriginelDir/model_.31-0.024574.weights.h5
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 220s 746ms/step - accuracy: 0.9923 - dice_coef: 0.5318 - dice_coef_edema: 0.6491 - dice_coef_enhancing: 0.5456 - dice_coef_necrotic: 0.4215 - loss: 0.0210 - mean_io_u: 0.8283 - precision: 0.9946 - sensitivity: 0.9903 - specificity: 0.9982 - val_accuracy: 0.9918 - val_dice_coef: 0.5335 - val_dice_coef_edema: 0.6955 - val_dice_coef_enhancing: 0.5236 - val_dice_coef_necrotic: 0.4105 - val_loss: 0.0246 - val_mean_io_u: 0.8272 - val_precision: 0.9940 - val_sensitivity: 0.9898 - val_specificity: 0.9980 - learning_rate: 1.0000e-06
# Epoch 32/35
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 667ms/step - accuracy: 0.9921 - dice_coef: 0.5295 - dice_coef_edema: 0.6472 - dice_coef_enhancing: 0.5377 - dice_coef_necrotic: 0.4187 - loss: 0.0215 - mean_io_u: 0.8293 - precision: 0.9946 - sensitivity: 0.9899 - specificity: 0.9982
# Epoch 32: val_loss did not improve from 0.02457
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 260s 739ms/step - accuracy: 0.9921 - dice_coef: 0.5295 - dice_coef_edema: 0.6471 - dice_coef_enhancing: 0.5377 - dice_coef_necrotic: 0.4187 - loss: 0.0215 - mean_io_u: 0.8293 - precision: 0.9946 - sensitivity: 0.9899 - specificity: 0.9982 - val_accuracy: 0.9918 - val_dice_coef: 0.5338 - val_dice_coef_edema: 0.6954 - val_dice_coef_enhancing: 0.5236 - val_dice_coef_necrotic: 0.4101 - val_loss: 0.0246 - val_mean_io_u: 0.8274 - val_precision: 0.9940 - val_sensitivity: 0.9898 - val_specificity: 0.9980 - learning_rate: 1.0000e-06
# Epoch 33/35
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 662ms/step - accuracy: 0.9918 - dice_coef: 0.5270 - dice_coef_edema: 0.6527 - dice_coef_enhancing: 0.5374 - dice_coef_necrotic: 0.4078 - loss: 0.0223 - mean_io_u: 0.8283 - precision: 0.9943 - sensitivity: 0.9895 - specificity: 0.9981
# Epoch 33: val_loss did not improve from 0.02457
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 237s 801ms/step - accuracy: 0.9918 - dice_coef: 0.5270 - dice_coef_edema: 0.6527 - dice_coef_enhancing: 0.5373 - dice_coef_necrotic: 0.4078 - loss: 0.0223 - mean_io_u: 0.8283 - precision: 0.9943 - sensitivity: 0.9895 - specificity: 0.9981 - val_accuracy: 0.9918 - val_dice_coef: 0.5338 - val_dice_coef_edema: 0.6953 - val_dice_coef_enhancing: 0.5241 - val_dice_coef_necrotic: 0.4106 - val_loss: 0.0246 - val_mean_io_u: 0.8274 - val_precision: 0.9940 - val_sensitivity: 0.9898 - val_specificity: 0.9980 - learning_rate: 1.0000e-06
# Epoch 34/35
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 645ms/step - accuracy: 0.9920 - dice_coef: 0.5255 - dice_coef_edema: 0.6378 - dice_coef_enhancing: 0.5283 - dice_coef_necrotic: 0.4160 - loss: 0.0214 - mean_io_u: 0.8269 - precision: 0.9946 - sensitivity: 0.9899 - specificity: 0.9982
# Epoch 34: val_loss did not improve from 0.02457
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 236s 714ms/step - accuracy: 0.9920 - dice_coef: 0.5255 - dice_coef_edema: 0.6378 - dice_coef_enhancing: 0.5283 - dice_coef_necrotic: 0.4160 - loss: 0.0214 - mean_io_u: 0.8270 - precision: 0.9946 - sensitivity: 0.9899 - specificity: 0.9982 - val_accuracy: 0.9918 - val_dice_coef: 0.5340 - val_dice_coef_edema: 0.6953 - val_dice_coef_enhancing: 0.5239 - val_dice_coef_necrotic: 0.4105 - val_loss: 0.0246 - val_mean_io_u: 0.8276 - val_precision: 0.9940 - val_sensitivity: 0.9898 - val_specificity: 0.9980 - learning_rate: 1.0000e-06
# Epoch 35/35
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 0s 655ms/step - accuracy: 0.9926 - dice_coef: 0.5211 - dice_coef_edema: 0.6226 - dice_coef_enhancing: 0.5281 - dice_coef_necrotic: 0.4125 - loss: 0.0203 - mean_io_u: 0.8294 - precision: 0.9948 - sensitivity: 0.9907 - specificity: 0.9983
# Epoch 35: val_loss did not improve from 0.02457
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 266s 728ms/step - accuracy: 0.9926 - dice_coef: 0.5212 - dice_coef_edema: 0.6226 - dice_coef_enhancing: 0.5281 - dice_coef_necrotic: 0.4125 - loss: 0.0203 - mean_io_u: 0.8294 - precision: 0.9948 - sensitivity: 0.9907 - specificity: 0.9983 - val_accuracy: 0.9918 - val_dice_coef: 0.5342 - val_dice_coef_edema: 0.6951 - val_dice_coef_enhancing: 0.5239 - val_dice_coef_necrotic: 0.4102 - val_loss: 0.0246 - val_mean_io_u: 0.8280 - val_precision: 0.9940 - val_sensitivity: 0.9899 - val_specificity: 0.9980 - learning_rate: 1.0000e-06

# %%
model.save("/content/unetOriginelDir/my_unetOriginel_model.keras")

# %% [markdown]
# # 10. Chargement du Modèle Entraîné
#
# Nous allons charger notre modèle de réseau de neurones entraîné en utilisant **Keras**. La méthode `load_model` nous permet de recharger le modèle sauvegardé, y compris les métriques personnalisées et les fonctions de perte définies lors de l'entraînement. Voici comment procéder :

# %%
from keras.saving import load_model
model = load_model('/content/unetOriginelDir/my_unetOriginel_model.keras',
                                   custom_objects={"accuracy" : tf.keras.metrics.MeanIoU(num_classes=4),
                                                   "dice_coef" : dice_coef,
                                                   "precision" : precision,
                                                   "sensitivity" :sensitivity,
                                                   "specificity" :specificity,
                                                   "dice_coef_necrotic" : dice_coef_necrotic,
                                                   "dice_coef_edema" : dice_coef_edema,
                                                   "dice_coef_enhancing" : dice_coef_enhancing
                                                  }, compile=False)

# %% [markdown]
# Nous spécifions le chemin vers notre modèle sauvegardé et fournissons un dictionnaire d'`custom_objects` pour garantir que nos métriques et fonctions de perte personnalisées soient correctement reconnues par **Keras**. En définissant `compile=False`, nous pouvons charger l'architecture et les poids du modèle sans le compiler immédiatement, ce qui nous permet d'ajuster les paramètres de compilation si nécessaire.

# %% [markdown]
# # 11. Analyse des Métriques
#
# Maintenant que l'entraînement est terminé, nous pouvons examiner le callback **CSVLogger** pour obtenir des informations sur le processus d'entraînement et les performances de notre modèle. Le **CSVLogger** enregistre des métriques telles que l'exactitude, la perte, le coefficient de Dice et la Mean IoU pour chaque époque, ce qui nous permet de suivre les progrès du modèle au fil du temps. En analysant ce journal, nous pouvons identifier des tendances, évaluer l'efficacité de notre stratégie d'entraînement et prendre des décisions éclairées pour les améliorations futures. Cette revue approfondie garantit que notre modèle fonctionne de manière optimale et est prêt pour le déploiement.

# %%
history = pd.read_csv('/content/unetOriginelDir/training.log', sep=',', engine='python')

hist=history

acc=hist['accuracy']
val_acc=hist['val_accuracy']

epoch=range(len(acc))

loss=hist['loss']
val_loss=hist['val_loss']

train_dice=hist['dice_coef']
val_dice=hist['val_dice_coef']

precision =hist['precision']
val_precision=hist['val_precision']

sensitivity= hist['sensitivity']
val_sensitivity= hist['val_sensitivity']

specificity= hist['specificity']
val_specificity= hist['val_specificity']

dice_coef_necrotic= hist['dice_coef_necrotic']
val_dice_coef_necrotic= hist['val_dice_coef_necrotic']

dice_coef_edema = hist['dice_coef_edema']
val_dice_coef_edema = hist['val_dice_coef_edema']

dice_coef_enhancing= hist['dice_coef_enhancing']
val_dice_coef_enhancing= hist['val_dice_coef_enhancing']

f, ax = plt.subplots(1, 4, figsize=(12, 4))

ax[0].plot(epoch, acc, 'b', label='Training Accuracy')
ax[0].plot(epoch, val_acc, 'r', label='Validation Accuracy')
ax[0].legend()

ax[1].plot(epoch, loss, 'b', label='Training Loss')
ax[1].plot(epoch, val_loss, 'r', label='Validation Loss')
ax[1].legend()

ax[2].plot(epoch, train_dice, 'b', label='Training dice coef')
ax[2].plot(epoch, val_dice, 'r', label='Validation dice coef')
ax[2].legend()

ax[3].plot(epoch, hist['mean_io_u'], 'b', label='Training mean IOU')
ax[3].plot(epoch, hist['val_mean_io_u'], 'r', label='Validation mean IOU')
ax[3].legend()

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(1, 3, figsize=(12, 4))

# 1. Precision
ax[0].plot(epoch, hist['precision'], 'b', label='Training Precision')
ax[0].plot(epoch, hist['val_precision'], 'r', label='Validation Precision')
ax[0].set_title('Precision')
ax[0].set_xlabel('Epoch')
ax[0].set_ylabel('Score')
ax[0].legend()
ax[0].grid(True)

# 2. Sensitivity (Recall)
ax[1].plot(epoch, hist['sensitivity'], 'b', label='Training Sensitivity')
ax[1].plot(epoch, hist['val_sensitivity'], 'r', label='Validation Sensitivity')
ax[1].set_title('Sensitivity (Recall)')
ax[1].set_xlabel('Epoch')
ax[1].set_ylabel('Score')
ax[1].legend()
ax[1].grid(True)

# 3. Specificity
ax[2].plot(epoch, hist['specificity'], 'b', label='Training Specificity')
ax[2].plot(epoch, hist['val_specificity'], 'r', label='Validation Specificity')
ax[2].set_title('Specificity')
ax[2].set_xlabel('Epoch')
ax[2].set_ylabel('Score')
ax[2].legend()
ax[2].grid(True)

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 4))

# Dice Coef - Necrotic
ax[0].plot(epoch, dice_coef_necrotic, 'b', label='Training Necrotic')
ax[0].plot(epoch, val_dice_coef_necrotic, 'r', label='Validation Necrotic')
ax[0].set_title('Dice Coefficient - Necrotic')
ax[0].set_xlabel('Epoch')
ax[0].set_ylabel('Score')
ax[0].legend()
ax[0].grid(True)

# Dice Coef - Edema
ax[1].plot(epoch, dice_coef_edema, 'b', label='Training Edema')
ax[1].plot(epoch, val_dice_coef_edema, 'r', label='Validation Edema')
ax[1].set_title('Dice Coefficient - Edema')
ax[1].set_xlabel('Epoch')
ax[1].set_ylabel('Score')
ax[1].legend()
ax[1].grid(True)

# Dice Coef - Enhancing Tumor
ax[2].plot(epoch, dice_coef_enhancing, 'b', label='Training Enhancing')
ax[2].plot(epoch, val_dice_coef_enhancing, 'r', label='Validation Enhancing')
ax[2].set_title('Dice Coefficient - Enhancing Tumor')
ax[2].set_xlabel('Epoch')
ax[2].set_ylabel('Score')
ax[2].legend()
ax[2].grid(True)

plt.tight_layout()
plt.show()

# %%
# Paramètres globaux
IMG_SIZE = 128
VOLUME_SLICES = 64
VOLUME_START_AT = 24

# %% [markdown]
# # 12. Prédire les Segmentations de Tumeurs
#
# Une fois que notre modèle est entraîné, nous pouvons l'utiliser pour prédire les segmentations des tumeurs sur de nouvelles images. Cela nous permet d'analyser les résultats de segmentation du modèle sur des données inédites, en comparant les prédictions aux segmentations de référence (ground truth). Pour ce faire, nous utilisons la méthode `.predict()` de Keras, qui génère les prédictions sur des échantillons d'images en entrée. Ces prédictions peuvent ensuite être visualisées ou utilisées pour calculer des métriques de performance supplémentaires.
# ```

# %%
from skimage import morphology

def postprocess_mask(mask_pred, min_size=20, hole_size=20):
    """
    Post-traitement minimal pour améliorer la segmentation :
    - Suppression des petits objets (faux positifs isolés)
    - Remplissage des petits trous dans les régions segmentées
    - Lissage morphologique par ouverture
    """
    mask_pp = np.zeros_like(mask_pred)
    classes = np.unique(mask_pred)
    for c in classes:
        if c == 0:
            continue  # Ne pas traiter le fond
        mask_c = (mask_pred == c)

        # Suppression des petits objets
        mask_c = morphology.remove_small_objects(mask_c, min_size=min_size)

        # Remplissage des petits trous
        mask_c = morphology.remove_small_holes(mask_c, area_threshold=hole_size)

        # Lissage morphologique (ouverture)
        selem = morphology.disk(2)  # élément structurant circulaire de rayon 2 pixels
        mask_c = morphology.opening(mask_c, selem)

        mask_pp[mask_c] = c
    return mask_pp

# %%
def prediction_func(case_path, case):
    # Initialiser le tableau d'entrée
    X = np.empty((VOLUME_SLICES, IMG_SIZE, IMG_SIZE, 3))  # 3 modalités : FLAIR, T1CE, T2

    # Charger les modalités
    vol_path = os.path.join(case_path, f'BraTS20_Training_{case}_flair.nii')
    flair = nib.load(vol_path).get_fdata()
    vol_path = os.path.join(case_path, f'BraTS20_Training_{case}_t1ce.nii')
    t1ce = nib.load(vol_path).get_fdata()
    vol_path = os.path.join(case_path, f'BraTS20_Training_{case}_t2.nii')
    t2 = nib.load(vol_path).get_fdata()

    # Redimensionner et stocker les slices
    for j in range(VOLUME_SLICES):
        X[j, :, :, 0] = cv2.resize(flair[:, :, j + VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))
        X[j, :, :, 1] = cv2.resize(t1ce[:, :, j + VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))
        X[j, :, :, 2] = cv2.resize(t2[:, :, j + VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))

    # Normaliser les données
    X = X / np.max(X)

    # Prédiction brute du modèle
    y_pred = model.predict(X, verbose=1)
    mask_pred = np.argmax(y_pred, axis=-1)

    # Post-traitement slice par slice
    mask_post = np.zeros_like(mask_pred)
    for i in range(mask_pred.shape[0]):
        mask_post[i] = postprocess_mask(mask_pred[i], min_size=20, hole_size=20)

    # Retourne aussi X pour la visualisation/Grad-CAM
    return mask_post, X

# %%
def get_grad_cam(model, img_array, layer_name="conv2d_3"):

    grad_model = tf.keras.models.Model([model.inputs], [model.get_layer(layer_name).output, model.output])

    with tf.GradientTape() as tape:
        inputs = tf.cast(img_array[np.newaxis, ...], tf.float32)
        conv_outputs, predictions = grad_model(inputs)
        pred_index = tf.argmax(tf.reduce_max(predictions, axis=(1,2)), axis=-1)
        loss = predictions[:, :, :, pred_index[0]]
        loss = tf.reduce_mean(loss)

    grads = tape.gradient(loss, conv_outputs)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))
    conv_outputs = conv_outputs[0]
    heatmap = tf.reduce_sum(tf.multiply(pooled_grads, conv_outputs), axis=-1)
    heatmap = np.maximum(heatmap, 0)
    if np.max(heatmap) != 0:
        heatmap /= np.max(heatmap)
    return heatmap #.numpy()

# %%
def visualize_predicted_class(case, start_slice=60):


    # Définir le chemin du cas
    path = f"/content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_{case}"

    # Charger les données
    gt = nib.load(os.path.join(path, f'BraTS20_Training_{case}_seg.nii')).get_fdata()
    origImage = nib.load(os.path.join(path, f'BraTS20_Training_{case}_flair.nii')).get_fdata()

    # Effectuer la prédiction (retourne maintenant un masque de classes entières)
    p, X = prediction_func(path, case)  # p: masques, X: slices d'entrée

    slice_idx = start_slice
    img_slice = X[slice_idx]  # (IMG_SIZE, IMG_SIZE, 3)

    # Calculer Grad-CAM (adapter le nom de la couche à ton modèle)
    heatmap = get_grad_cam(model, img_slice, layer_name="conv2d_3")
    heatmap = cv2.resize(heatmap, (IMG_SIZE, IMG_SIZE))
    heatmap = np.uint8(255 * heatmap)
    heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
    img_slice_vis = np.uint8(255 * (img_slice - np.min(img_slice)) / (np.ptp(img_slice) + 1e-8))
    if img_slice_vis.shape[2] == 1:
        img_slice_vis = np.repeat(img_slice_vis, 3, axis=2)
    superimposed_img = cv2.addWeighted(img_slice_vis, 0.6, heatmap, 0.4, 0)

    # Préparation des masques pour affichage
    pred_slice = p[slice_idx]
    predicted_colors = np.zeros((IMG_SIZE, IMG_SIZE, 3))
    predicted_colors[pred_slice == 1] = [1, 0, 0]   # Nécrose en rouge
    predicted_colors[pred_slice == 2] = [0, 1, 0]   # Œdème en vert
    predicted_colors[(pred_slice == 3) | (pred_slice == 4)] = [0, 0, 1]   # Zone améliorante en bleu

    necrose_mask = (pred_slice == 1).astype(float)
    edema_mask = (pred_slice == 2).astype(float)
    enhancing_mask = ((pred_slice == 3) | (pred_slice == 4)).astype(float)

    curr_gt = cv2.resize(gt[:, :, slice_idx + VOLUME_START_AT], (IMG_SIZE, IMG_SIZE), interpolation=cv2.INTER_NEAREST)
    gt_colors = np.zeros((*curr_gt.shape, 3))
    gt_colors[curr_gt == 1] = [1, 0, 0]
    gt_colors[curr_gt == 2] = [0, 1, 0]
    gt_colors[(curr_gt == 3) | (curr_gt == 4)] = [0, 0, 1]

    flair_slice = cv2.resize(origImage[:, :, slice_idx + VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))

    plt.figure(figsize=(24, 10))
    f, axarr = plt.subplots(1, 7, figsize=(24, 10))

    for i in range(7):
        if i < 6:
            axarr[i].imshow(flair_slice, cmap="gray", interpolation='none')
        axarr[i].axis('off')

    axarr[0].set_title('Original Image (FLAIR)')
    axarr[1].imshow(gt_colors, interpolation='none', alpha=0.3)
    axarr[1].set_title('Ground Truth')
    axarr[2].imshow(predicted_colors, interpolation='none', alpha=0.3)
    axarr[2].set_title('All Classes Predicted')
    axarr[3].imshow(edema_mask, cmap="Greens", alpha=0.3)
    axarr[3].set_title('Edema Predicted')
    axarr[4].imshow(necrose_mask, cmap="Reds", alpha=0.3)
    axarr[4].set_title('Necrotic Core Predicted')
    axarr[5].imshow(enhancing_mask, cmap="Blues", alpha=0.3)
    axarr[5].set_title('Enhancing Tumor Predicted')
    axarr[6].imshow(superimposed_img)
    axarr[6].set_title('Grad-CAM')
    axarr[6].axis('off')

    plt.tight_layout()
    plt.show()

# %%
visualize_predicted_class(case='004', start_slice=60)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 71ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: [['input_layer']]
# Received: inputs=Tensor(shape=(1, 128, 128, 3))
#   warnings.warn(msg)

# %%
visualize_predicted_class(case='005', start_slice=60)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step

# %%
visualize_predicted_class(case='010', start_slice=60)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step

# %%
import random

# %%
def predict_segmentation(sample_path):
    """
    Prédit la segmentation tumorale pour un volume IRM multimodal.
    Retourne le masque segmenté (post-traité) et les slices d'entrée (pour XAI).
    """
    # Charger les chemins des modalités
    t1ce_path = sample_path + '_t1ce.nii'
    flair_path = sample_path + '_flair.nii'
    t2_path = sample_path + '_t2.nii'

    # Extraire les données des modalités
    t1ce = nib.load(t1ce_path).get_fdata()
    flair = nib.load(flair_path).get_fdata()
    t2 = nib.load(t2_path).get_fdata()

    # Créer un tableau vide pour les données d'entrée
    X = np.empty((VOLUME_SLICES, IMG_SIZE, IMG_SIZE, 3))  # 3 modalités : FLAIR, T1CE, T2

    # Redimensionner et stocker les slices
    for j in range(VOLUME_SLICES):
        X[j, :, :, 0] = cv2.resize(flair[:, :, j + VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))
        X[j, :, :, 1] = cv2.resize(t1ce[:, :, j + VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))
        X[j, :, :, 2] = cv2.resize(t2[:, :, j + VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))

    # Normaliser les données (sécurisé)
    max_val = np.max(X)
    if max_val > 0:
        X = X / max_val

    # Prédiction brute du modèle
    y_pred = model.predict(X, verbose=1)  # (VOLUME_SLICES, IMG_SIZE, IMG_SIZE, n_classes)
    mask_pred = np.argmax(y_pred, axis=-1)  # (VOLUME_SLICES, IMG_SIZE, IMG_SIZE)

    # Post-traitement slice par slice
    mask_post = np.zeros_like(mask_pred)
    for i in range(mask_pred.shape[0]):
        mask_post[i] = postprocess_mask(mask_pred[i], min_size=100)

    # Retourne le masque segmenté et les slices d'entrée (pour XAI/Grad-CAM)
    return mask_post, X

# %%
def show_predicted_segmentations(samples_list, slice_to_plot, cmap='viridis', norm=None):
    """
    Affiche les segmentations prédites et réelles pour un échantillon aléatoire.
    """
    # Choisir un patient aléatoire
    random_sample = random.choice(samples_list)
    random_sample_path = os.path.join(TRAIN_DATASET_PATH, random_sample, random_sample)

    # Prédire la segmentation du patient (retourne mask_post, X)
    predicted_seg, _ = predict_segmentation(random_sample_path)

    # Charger la segmentation originale (Ground truth)
    seg_path = random_sample_path + '_seg.nii'
    seg = nib.load(seg_path).get_fdata()

    # Redimensionner la segmentation originale pour correspondre aux prédictions
    seg_resized = cv2.resize(
        seg[:, :, slice_to_plot + VOLUME_START_AT],
        (IMG_SIZE, IMG_SIZE),
        interpolation=cv2.INTER_NEAREST
    )

    # Extraire la slice prédite
    pred_slice = predicted_seg[slice_to_plot]  # (IMG_SIZE, IMG_SIZE)

    # Créer des masques binaires pour chaque classe
    background = (pred_slice == 0).astype(float)
    core = (pred_slice == 1).astype(float)
    edema = (pred_slice == 2).astype(float)
    enhancing = ((pred_slice == 3) | (pred_slice == 4)).astype(float)  # selon ton mapping

    # Pour affichage "toutes classes" (RGB)
    all_classes = np.zeros((IMG_SIZE, IMG_SIZE, 3))
    all_classes[core == 1] = [1, 0, 0]      # Nécrose en rouge
    all_classes[edema == 1] = [0, 1, 0]     # Œdème en vert
    all_classes[enhancing == 1] = [0, 0, 1] # Zone améliorante en bleu

    print("Patient number:", random_sample)
    fig, axstest = plt.subplots(1, 6, figsize=(25, 20))

    # Segmentation originale
    axstest[0].imshow(seg_resized, cmap=cmap, norm=norm)
    axstest[0].set_title('Original Segmentation')

    # Toutes les classes prédites (affichage RGB)
    axstest[1].imshow(all_classes)
    axstest[1].set_title('Predicted Segmentation - All Classes')

    # Background
    axstest[2].imshow(background, cmap='gray')
    axstest[2].set_title('Predicted Segmentation - Background')

    # Nécrose/Core
    axstest[3].imshow(core, cmap='Reds')
    axstest[3].set_title('Predicted Segmentation - Necrotic/Core')

    # Œdème
    axstest[4].imshow(edema, cmap='Greens')
    axstest[4].set_title('Predicted Segmentation - Edema')

    # Zone améliorante
    axstest[5].imshow(enhancing, cmap='Blues')
    axstest[5].set_title('Predicted Segmentation - Enhancing')

    plt.subplots_adjust(wspace=0.8)
    plt.show()

# %%
show_predicted_segmentations(samples_list=train_patients, slice_to_plot=30)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Patient number: BraTS20_Training_354

# %%
show_predicted_segmentations(samples_list=train_patients, slice_to_plot=30)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Patient number: BraTS20_Training_147

# %%
show_predicted_segmentations(samples_list=train_patients, slice_to_plot=30)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Patient number: BraTS20_Training_177

# %%
# Définir les noms des classes
SEGMENT_CLASSES = {
    0: 'Background',
    1: 'Necrotic/Core',
    2: 'Edema',
    3: 'Enhancing'
}

# Sélectionner un cas spécifique
case = test_patients[3][-3:]  # Extraire l'identifiant du patient (exemple '003')
path = f"/content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_{case}"

# Charger la segmentation réelle (Ground Truth)
gt = nib.load(os.path.join(path, f'BraTS20_Training_{case}_seg.nii')).get_fdata()

# Effectuer la prédiction pour ce cas
mask_post, X = prediction_func(path, case)  # Dépaqueter le tuple

# Choisir la tranche à afficher
i = 40  # index de la slice

# Préparer le Ground Truth pour la classe spécifiée
eval_class = 2  # classe à évaluer (0=background, 1=nécrose, 2=œdème, 3=zone améliorante)
gt_copy = gt.copy()
gt_copy[gt_copy != eval_class] = 0
gt_copy[gt_copy == eval_class] = 1

# Redimensionner le Ground Truth pour correspondre à la taille du masque prédit
resized_gt = cv2.resize(
    gt_copy[:, :, i + VOLUME_START_AT],
    (IMG_SIZE, IMG_SIZE),
    interpolation=cv2.INTER_NEAREST
)

# Extraire la slice prédite et créer un masque binaire pour la classe évaluée
pred_slice = mask_post[i]  # masque 2D (IMG_SIZE, IMG_SIZE)
pred_class_mask = (pred_slice == eval_class).astype(float)

# Afficher les résultats
plt.figure(figsize=(10, 5))
f, axarr = plt.subplots(1, 2)

# Ground Truth
axarr[0].imshow(resized_gt, cmap="gray")
axarr[0].set_title('Ground Truth')

# Prédiction pour la classe spécifiée
axarr[1].imshow(pred_class_mask, cmap="gray")
axarr[1].set_title(f'Predicted Class: {SEGMENT_CLASSES[eval_class]}')

plt.tight_layout()
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step

# %% [markdown]
# # 13. Évaluation
#
# Appelons la fonction `evaluate()` pour évaluer les performances de notre modèle sur notre jeu de données de test :

# %%
import pandas as pd

# Évaluer le modèle sur les données de test
model.compile(
    loss="categorical_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    metrics=[
        'accuracy',
        tf.keras.metrics.MeanIoU(num_classes=4),
        dice_coef,
        precision,
        sensitivity,
        specificity,
        dice_coef_necrotic,
        dice_coef_edema,
        dice_coef_enhancing
    ]
)

# Évaluer le modèle
results = model.evaluate(test_generator, batch_size=100, callbacks=callbacks, verbose=0)

# Noms des métriques
descriptions = [
    "Loss", "Accuracy", "MeanIOU", "Dice coefficient", "Precision",
    "Sensitivity", "Specificity", "Dice coef Necrotic", "Dice coef Edema", "Dice coef Enhancing"
]

# Créer un DataFrame pour organiser les résultats
results_df = pd.DataFrame({
    "Metric": descriptions,
    "Value": [round(metric, 4) for metric in results]
})

# Afficher le DataFrame
print("\nModel evaluation on the test set:")
print("==================================")
print(results_df)

# Sauvegarder les résultats dans un fichier CSV (optionnel)
results_df.to_csv("/content/unetOriginelDir/model_evaluation_results.csv", index=False)
# Out:
# Model evaluation on the test set:
# ==================================
#                 Metric   Value
# 0                 Loss  0.0231
# 1             Accuracy  0.9919
# 2              MeanIOU  0.8270
# 3     Dice coefficient  0.4954
# 4            Precision  0.9943
# 5          Sensitivity  0.9898
# 6          Specificity  0.9981
# 7   Dice coef Necrotic  0.3720
# 8      Dice coef Edema  0.5770
# 9  Dice coef Enhancing  0.4849

# %%
# !mv /content/unetOriginelDir /content/drive/MyDrive/
